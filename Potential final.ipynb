# %%
import pandas as pd
import statistics as stats
import numpy as np
import re
import matplotlib.pyplot as plt
from scipy.stats import norm
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import binom

from scipy.stats import poisson
from scipy.stats.mstats import winsorize
import scipy.stats as stats
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error,explained_variance_score
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import (GridSearchCV, cross_val_score, cross_val_predict, StratifiedKFold, learning_curve)

#from statsmodels.tools.eval_measures import mse, rmse
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install -U statsmodels

# %%
pip install prettytable

# %%
DublinAvgCarsWeekly = pd.read_csv("Average weekly volume of cars for selected traffic count sites.csv")
#https://data.gov.ie/dataset/tha21-average-weekly-volume-of-cars-for-selected-traffic-count-sites

GBData = pd.read_csv("GBData.csv")
#https://www.gov.uk/government/statistics/transport-use-during-the-coronavirus-covid-19-pandemic

London = pd.read_csv("tfl-journeys-type.csv")
#https://data.london.gov.uk/dataset/public-transport-journeys-type-transport

Dublin = pd.read_csv("dublin.csv")


DublinBus = pd.read_csv("DublinBus.csv")
#https://data.gov.ie/dataset/tha25-passenger-journeys-by-public-transport
    
DublinLuas = pd.read_csv("DublinLuas.csv")
#https://data.gov.ie/dataset/tii03-passenger-journeys-by-luas

DublinBus2 = pd.read_csv("NonDublinBus.csv")
#https://data.gov.ie/dataset/tha25-passenger-journeys-by-public-transport

DublinRail = pd.read_csv("Rail.csv")
#https://data.gov.ie/dataset/tha25-passenger-journeys-by-public-transport

Australia = pd.read_csv("Aus.csv")


#base statistics of population for city and country. take into consideration wanted to use
#dublin to include dublin bus.... other counties skew bus data as theres no metro bus everyone drives.

# %%
Dublin.head(20)
# Out:
#    STATISTIC     Statistic Label TLIST(W1)          Week  C03935V04687  \
# 0   THA25C01  Passenger Journeys   2019W01  2019 Week 01            10
# 1   THA25C01  Passenger Journeys   2019W01  2019 Week 01            20
# 2   THA25C01  Passenger Journeys   2019W01  2019 Week 01            30
# 3   THA25C01  Passenger Journeys   2019W01  2019 Week 01            40
# 4   THA25C01  Passenger Journeys   2019W02  2019 Week 02            10
# 5   THA25C01  Passenger Journeys   2019W02  2019 Week 02            20
# 6   THA25C01  Passenger Journeys   2019W02  2019 Week 02            30
# 7   THA25C01  Passenger Journeys   2019W02  2019 Week 02            40
# 8   THA25C01  Passenger Journeys   2019W03  2019 Week 03            10
# 9   THA25C01  Passenger Journeys   2019W03  2019 Week 03            20
# 10  THA25C01  Passenger Journeys   2019W03  2019 Week 03            30
# 11  THA25C01  Passenger Journeys   2019W03  2019 Week 03            40
# 12  THA25C01  Passenger Journeys   2019W04  2019 Week 04            10
# 13  THA25C01  Passenger Journeys   2019W04  2019 Week 04            20
# 14  THA25C01  Passenger Journeys   2019W04  2019 Week 04            30
# 15  THA25C01  Passenger Journeys   2019W04  2019 Week 04            40
# 16  THA25C01  Passenger Journeys   2019W05  2019 Week 05            10
# 17  THA25C01  Passenger Journeys   2019W05  2019 Week 05            20
# 18  THA25C01  Passenger Journeys   2019W05  2019 Week 05            30
# 19  THA25C01  Passenger Journeys   2019W05  2019 Week 05            40
#
#                        Mode of Transport    UNIT      VALUE
# 0                       Dublin Metro Bus  Number  1987891.0
# 1            Bus, excluding Dublin Metro  Number   497598.0
# 2                                   Rail  Number        NaN
# 3   All public transport, excluding LUAS  Number  2485489.0
# 4                       Dublin Metro Bus  Number  2709579.0
# 5            Bus, excluding Dublin Metro  Number   633764.0
# 6                                   Rail  Number        NaN
# 7   All public transport, excluding LUAS  Number  3343343.0
# 8                       Dublin Metro Bus  Number  2784678.0
# 9            Bus, excluding Dublin Metro  Number   678097.0
# 10                                  Rail  Number        NaN
# 11  All public transport, excluding LUAS  Number  3462775.0
# 12                      Dublin Metro Bus  Number  2858346.0
# 13           Bus, excluding Dublin Metro  Number   676140.0
# 14                                  Rail  Number        NaN
# 15  All public transport, excluding LUAS  Number  3534486.0
# 16                      Dublin Metro Bus  Number  2924821.0
# 17           Bus, excluding Dublin Metro  Number   672440.0
# 18                                  Rail  Number        NaN
# 19  All public transport, excluding LUAS  Number  3597261.0

# %%
Australia["Year"].unique()
# Out:
# array([2018., 2019., 2020., 2021., 2022., 2023.,   nan])

# %%
Australia1 = Australia.isna()
print(Australia1)
# Out:
#      Year  Month  Month name  Metropolitan train  Metropolitan tram  \
# 0   False  False       False               False              False
# 1   False  False       False               False              False
# 2   False  False       False               False              False
# 3   False  False       False               False              False
# 4   False  False       False               False              False
# ..    ...    ...         ...                 ...                ...
# 71   True   True        True                True               True
# 72   True   True        True                True               True
# 73   True   True        True                True               True
# 74   True   True        True                True               True
# 75   True   True        True                True               True
#
#     Metropolitan bus  Regional train  Regional coach  Regional bus  \
# 0              False           False           False         False
# 1              False           False           False         False
# 2              False           False           False         False
# 3              False           False           False         False
# 4              False           False           False         False
# ..               ...             ...             ...           ...
# 71              True            True            True          True
# 72              True            True            True          True
# 73              True            True            True          True
# 74              True            True            True          True
# 75              True            True            True          True
#
#     Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0         True         True         True         True
# 1         True         True         True         True
# 2         True         True         True         True
# 3         True         True         True         True
# 4         True         True         True         True
# ..         ...          ...          ...          ...
# 71        True         True         True         True
# 72        True         True         True         True
# 73        True         True         True         True
# 74        True         True         True         True
# 75        True         True         True         True
#
# [76 rows x 13 columns]

# %%
Australia = Australia.drop(columns=['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'], axis = 1)

# %%
Australia = Australia.dropna()
#Rows with NAN dropped

# %%
GBData["date"].unique()
#need to change daily to average weekly values and maybe get percentage of the population
#do i just want car values?
# Out:
# array(['2020-03-01', '2020-03-02', '2020-03-03', ..., '2023-12-09',
#        '2023-12-10', '2023-12-11'], dtype=object)

# %%
London.tail(50)
#compare 2019 - 2023 for bus trains trams. take into consideration the proportion of london goers that take the,
#underground as this takes away from other transport and have it as a percentage.
# Out:
#     Period and Financial year  Reporting Period  Days in period  \
# 127                  11_19/20                11              28
# 128                  12_19/20                12              28
# 129                  13_19/20                13              29
# 130                  01_19/20                 1              28
# 131                  02_19/20                 2              28
# 132                  03_19/20                 3              28
# 133                  04_19/20                 4              28
# 134                  05_19/20                 5              28
# 135                  06_19/20                 6              28
# 136                  07_19/20                 7              28
# 137                  08_19/20                 8              28
# 138                  09_19/20                 9              28
# 139                  10_19/20                10              28
# 140                  11_19/20                11              28
# 141                  12_19/20                12              28
# 142                  13_19/20                13              29
# 143                  01_21/22                 1              31
# 144                  02_21/22                 2              28
# 145                  03_21/22                 3              28
# 146                  04_21/22                 4              28
# 147                  05_21/22                 5              28
# 148                  06_21/22                 6              28
# 149                  07_21/22                 7              28
# 150                  08_21/22                 8              28
# 151                  09_21/22                 9              28
# 152                  10_21/22                10              28
# 153                  11_21/22                11              28
# 154                  12_21/22                12              28
# 155                  13_21/22                13              26
# 156                  01_22/23                 1              30
# 157                  02_22/23                 2              28
# 158                  03_22/23                 3              28
# 159                  04_22/23                 4              28
# 160                  05_22/23                 5              28
# 161                  06_22/23                 6              28
# 162                  07_22/23                 7              28
# 163                  08_22/23                 8              28
# 164                  09_22/23                 9              28
# 165                  10_22/23                10              28
# 166                  11_22/23                11              28
# 167                  12_22/23                12              28
# 168                  13_22/23                13              27
# 169                  01_23/24                 1              29
# 170                  02_23/24                 2              28
# 171                  03_23/24                 3              28
# 172                  04_23/24                 4              28
# 173                  05_23/24                 5              28
# 174                  06_23/24                 6              28
# 175                  07_23/24                 7              28
# 176                  08_23/24                 8              28
#
#     Period beginning Period ending  Bus journeys (m)  \
# 127        05-Jan-20     01-Feb-20             169.4
# 128        02-Feb-20     29-Feb-20             165.2
# 129        01-Mar-20     31-Mar-20             126.4
# 130        01-Apr-20     02-May-20              30.2
# 131        03-May-20     30-May-20              32.5
# 132        31-May-20     27-Jun-20              47.0
# 133        28-Jun-20     25-Jul-20              66.7
# 134        26-Jul-20     22-Aug-20              75.2
# 135        23-Aug-20     19-Sep-20              94.8
# 136        20-Sep-20     17-Oct-20             102.0
# 137        18-Oct-20     14-Nov-20              88.9
# 138        15-Nov-20     12-Dec-20              89.0
# 139        13-Dec-20     09-Jan-21              57.5
# 140        10-Jan-21     06-Feb-21              51.6
# 141        07-Feb-21     06-Mar-21              56.9
# 142        07-Mar-21     31-Mar-21              72.9
# 143        01-Apr-21     01-May-21              95.9
# 144        02-May-21     29-May-21             104.3
# 145        30-May-21     26-Jun-21             107.0
# 146        27-Jun-21     24-Jul-21             109.1
# 147        25-Jul-21     21-Aug-21              98.8
# 148        22-Aug-21     18-Sep-21             115.5
# 149        19-Sep-21     16-Oct-21             130.2
# 150        17-Oct-21     13-Nov-21             125.4
# 151        14-Nov-21     11-Dec-21             131.3
# 152        12-Dec-21     08-Jan-22              95.1
# 153        09-Jan-22     05-Feb-22             123.5
# 154        06-Feb-22     05-Mar-22             127.8
# 155        06-Mar-22     31-Mar-22             126.7
# 156        01-Apr-22     30-Apr-22             135.0
# 157        01-May-22     28-May-22             140.5
# 158        29-May-22     25-Jun-22             138.0
# 159        26-Jun-22     23-Jul-22             137.8
# 160        24-Jul-22     20-Aug-22             122.5
# 161        21-Aug-22     17-Sep-22             132.9
# 162        18-Sep-22     15-Oct-22             147.0
# 163        16-Oct-22     12-Nov-22             143.1
# 164        13-Nov-22     10-Dec-22             146.0
# 165        11-Dec-22     07-Jan-23             116.9
# 166        08-Jan-23     04-Feb-23             141.3
# 167        05-Feb-23     04-Mar-23             141.6
# 168        05-Mar-23     31-Mar-23             142.2
# 169        01-Apr-23     29-Apr-23             140.9
# 170        30-Apr-23     27-May-23             146.0
# 171        28-May-23     24-Jun-23             145.8
# 172        25-Jun-23     22-Jul-23             147.1
# 173        23-Jul-23     19-Aug-23             129.7
# 174        20-Aug-23     16-Sep-23             139.6
# 175        17-Sep-23     14-Oct-23             155.4
# 176        15-Oct-23     11-Nov-23             146.4
#
#      Underground journeys (m)  DLR Journeys (m)  Tram Journeys (m)  \
# 127                     105.8               9.2                2.3
# 128                     106.2               9.3                2.2
# 129                      60.9               6.1                1.6
# 130                       5.7               1.2                0.4
# 131                       6.7               1.4                0.5
# 132                      13.3               2.1                0.7
# 133                      22.2               2.9                1.0
# 134                      28.8               3.6                1.0
# 135                      36.3               4.2                1.2
# 136                      39.5               4.5                1.4
# 137                      33.7               4.1                1.0
# 138                      32.1               4.0                1.1
# 139                      18.8               2.7                0.7
# 140                      16.8               2.7                0.7
# 141                      19.8               3.1                0.8
# 142                      22.4               3.3                1.0
# 143                      37.4               4.9                1.3
# 144                      42.5               5.0                1.5
# 145                      48.6               5.6                1.5
# 146                      49.6               5.4                1.5
# 147                      51.6               5.5                1.3
# 148                      58.2               5.9                1.2
# 149                      69.7               7.1                1.7
# 150                      73.7               7.2                1.7
# 151                      75.8               7.0                1.6
# 152                      45.4               4.6                1.2
# 153                      60.2               5.9                1.6
# 154                      65.4               6.5                1.4
# 155                      70.4               6.6                1.5
# 156                      79.2               7.1                1.6
# 157                      80.1               7.6                1.8
# 158                      71.7               6.7                1.7
# 159                      81.3               6.5                1.5
# 160                      73.9               6.4                1.5
# 161                      79.6               6.5                1.5
# 162                      88.2               7.6                1.6
# 163                      87.6               7.7                1.7
# 164                      95.1               7.6                1.6
# 165                      68.5               5.7                1.3
# 166                      85.2               7.4                1.8
# 167                      89.8               7.8                1.6
# 168                      84.9               7.6                1.7
# 169                      91.5               8.2                1.4
# 170                      88.2               7.7                1.6
# 171                      90.2               7.9                1.7
# 172                      94.1               7.9                1.6
# 173                      86.6               7.2                1.4
# 174                      83.7               7.3                1.7
# 175                      93.4               8.3                1.6
# 176                      95.8               7.8                1.3
#
#      Overground Journeys (m)  London Cable Car Journeys (m)  \
# 127                     14.1                            0.1
# 128                     15.6                            0.1
# 129                     13.0                            0.0
# 130                      1.0                            0.0
# 131                      1.5                            0.0
# 132                      2.8                            0.0
# 133                      4.5                            0.0
# 134                      5.1                            0.1
# 135                      6.6                            0.1
# 136                      8.5                            0.0
# 137                      7.1                            0.0
# 138                      6.6                            0.0
# 139                      3.2                            0.0
# 140                      3.5                            0.0
# 141                      4.4                            0.1
# 142                      4.8                            0.1
# 143                      8.6                            0.1
# 144                      7.7                            0.1
# 145                      7.8                            0.1
# 146                     10.1                            0.1
# 147                      8.6                            0.2
# 148                     10.6                            0.2
# 149                     12.5                            0.1
# 150                     11.6                            0.1
# 151                     12.2                            0.1
# 152                      6.7                            0.1
# 153                     10.0                            0.1
# 154                     10.7                            0.1
# 155                     13.8                            0.1
# 156                     12.0                            0.1
# 157                     12.9                            0.1
# 158                     11.1                            0.1
# 159                     12.5                            0.1
# 160                     10.0                            0.2
# 161                     12.3                            0.1
# 162                     12.5                            0.1
# 163                     13.3                            0.1
# 164                     14.0                            0.1
# 165                      6.9                            0.1
# 166                     13.1                            0.1
# 167                     13.4                            0.1
# 168                     13.2                            0.1
# 169                     13.8                            0.1
# 170                     14.1                            0.1
# 171                     14.6                            0.1
# 172                     14.3                            0.1
# 173                     12.4                            0.2
# 174                     13.8                            0.1
# 175                     14.8                            0.1
# 176                     15.0                            0.1
#
#      TfL Rail Journeys (m)
# 127                    5.7
# 128                    5.2
# 129                    3.5
# 130                    0.6
# 131                    0.7
# 132                    1.2
# 133                    1.6
# 134                    2.0
# 135                    2.2
# 136                    2.5
# 137                    2.1
# 138                    2.1
# 139                    1.2
# 140                    1.2
# 141                    1.4
# 142                    1.5
# 143                    2.1
# 144                    2.3
# 145                    2.7
# 146                    2.8
# 147                    2.8
# 148                    3.1
# 149                    3.7
# 150                    3.7
# 151                    3.3
# 152                    2.4
# 153                    3.2
# 154                    3.1
# 155                    3.1
# 156                    4.4
# 157                    5.5
# 158                    8.1
# 159                   11.6
# 160                    9.2
# 161                    9.8
# 162                   11.0
# 163                   12.5
# 164                   15.2
# 165                    8.9
# 166                   13.4
# 167                   14.0
# 168                   14.0
# 169                   14.2
# 170                   15.1
# 171                   16.0
# 172                   16.7
# 173                   15.4
# 174                   15.6
# 175                   17.3
# 176                   17.8

# %%
London = London.drop(columns=['Period and Financial year', 'Reporting Period', 'Overground Journeys (m)',
                              'London Cable Car Journeys (m)', 'TfL Rail Journeys (m)', 'Period ending', 'Period ending', 'Days in period'], axis = 1)
London.head()
# Out:
#   Period beginning  Bus journeys (m)  Underground journeys (m)  \
# 0        01-Apr-10             189.1                      90.5
# 1        02-May-10             181.6                      84.5
# 2        30-May-10             175.9                      84.3
# 3        27-Jun-10             183.4                      86.5
# 4        25-Jul-10             160.4                      82.9
#
#    DLR Journeys (m)  Tram Journeys (m)
# 0               6.3                2.3
# 1               5.8                2.2
# 2               5.8                2.1
# 3               6.1                2.1
# 4               5.8                2.0

# %%
London['Period beginning'] = London['Period beginning'].str.slice(3)
London = London.iloc[114:,:]

#Removing rows up to Jan 2019

# %%
London
# Out:
#     Period beginning  Bus journeys (m)  Underground journeys (m)  \
# 114           Jan-19             171.3                     106.7
# 115           Feb-19             171.3                     110.8
# 116           Mar-19             182.7                     114.1
# 117           Apr-19             156.6                     101.2
# 118           Apr-19             175.2                     106.1
# ..               ...               ...                       ...
# 172           Jun-23             147.1                      94.1
# 173           Jul-23             129.7                      86.6
# 174           Aug-23             139.6                      83.7
# 175           Sep-23             155.4                      93.4
# 176           Oct-23             146.4                      95.8
#
#      DLR Journeys (m)  Tram Journeys (m)
# 114               9.3                2.2
# 115               9.7                2.2
# 116              10.0                2.2
# 117               8.9                2.0
# 118               9.7                2.2
# ..                ...                ...
# 172               7.9                1.6
# 173               7.2                1.4
# 174               7.3                1.7
# 175               8.3                1.6
# 176               7.8                1.3
#
# [63 rows x 5 columns]

# %%
DublinTransportData = DublinBus

# %%
DublinTransportData.head()
# Out:
#   STATISTIC     Statistic Label  TLIST(A1)  Year  C03935V04687  \
# 0  THA24C01  Passenger Journeys       2019  2019            10
# 1  THA24C01  Passenger Journeys       2019  2019            10
# 2  THA24C01  Passenger Journeys       2019  2019            10
# 3  THA24C01  Passenger Journeys       2019  2019            10
# 4  THA24C01  Passenger Journeys       2019  2019            10
#
#   Mode of Transport  C01198V01436 Weeks of the year    UNIT      VALUE
# 0  Dublin Metro Bus             1           Week 01  Number  1987891.0
# 1  Dublin Metro Bus             2           Week 02  Number  2709579.0
# 2  Dublin Metro Bus             3           Week 03  Number  2784678.0
# 3  Dublin Metro Bus             4           Week 04  Number  2858346.0
# 4  Dublin Metro Bus             5           Week 05  Number  2924821.0

# %%
DublinLuas.head()
# Out:
#   STATISTIC Statistic Label  TLIST(A1)  Year C01885V02316     Month    UNIT  \
# 0  TOA11C01        Red line       2018  2018           01   January  Number
# 1  TOA11C01        Red line       2018  2018           02  February  Number
# 2  TOA11C01        Red line       2018  2018           03     March  Number
# 3  TOA11C01        Red line       2018  2018           04     April  Number
# 4  TOA11C01        Red line       2018  2018           05       May  Number
#
#      VALUE
# 0  1664495
# 1  1657562
# 2  1661098
# 3  1794424
# 4  1934553

# %%
DublinLuas["Statistic Label"].unique()
# Out:
# array(['Red line', 'Green line', 'All Luas lines'], dtype=object)

# %%
Column_names = DublinLuas.columns.values.tolist()
Column_names
# Out:
# ['STATISTIC',
#  'Statistic Label',
#  'TLIST(A1)',
#  'Year',
#  'C01885V02316',
#  'Month',
#  'UNIT',
#  'VALUE']

# %%
DublinLuas1 = DublinLuas.drop(columns=['STATISTIC', 'TLIST(A1)', 'C01885V02316', 'UNIT'], axis = 1)
DublinLuas1
# Out:
#     Statistic Label  Year       Month     VALUE
# 0          Red line  2018     January   1664495
# 1          Red line  2018    February   1657562
# 2          Red line  2018       March   1661098
# 3          Red line  2018       April   1794424
# 4          Red line  2018         May   1934553
# ..              ...   ...         ...       ...
# 190  All Luas lines  2022   September   3811093
# 191  All Luas lines  2022     October   4219124
# 192  All Luas lines  2022    November   4375705
# 193  All Luas lines  2022    December   4030698
# 194  All Luas lines  2022  All months  38667875
#
# [195 rows x 4 columns]

# %%
DublinLuas1 = DublinLuas1[DublinLuas1["Statistic Label"].str.contains("All Luas lines") == True]
DublinLuas1
# Out:
#     Statistic Label  Year       Month     VALUE
# 130  All Luas lines  2018     January   3218649
# 131  All Luas lines  2018    February   3118289
# 132  All Luas lines  2018       March   3097570
# 133  All Luas lines  2018       April   3350056
# 134  All Luas lines  2018         May   3622338
# ..              ...   ...         ...       ...
# 190  All Luas lines  2022   September   3811093
# 191  All Luas lines  2022     October   4219124
# 192  All Luas lines  2022    November   4375705
# 193  All Luas lines  2022    December   4030698
# 194  All Luas lines  2022  All months  38667875
#
# [65 rows x 4 columns]

# %%
Dublin
# Out:
#      STATISTIC     Statistic Label TLIST(W1)          Week  C03935V04687  \
# 0     THA25C01  Passenger Journeys   2019W01  2019 Week 01            10
# 1     THA25C01  Passenger Journeys   2019W01  2019 Week 01            20
# 2     THA25C01  Passenger Journeys   2019W01  2019 Week 01            30
# 3     THA25C01  Passenger Journeys   2019W01  2019 Week 01            40
# 4     THA25C01  Passenger Journeys   2019W02  2019 Week 02            10
# ...        ...                 ...       ...           ...           ...
# 1035  THA25C01  Passenger Journeys   2023W47  2023 Week 47            40
# 1036  THA25C01  Passenger Journeys   2023W48  2023 Week 48            10
# 1037  THA25C01  Passenger Journeys   2023W48  2023 Week 48            20
# 1038  THA25C01  Passenger Journeys   2023W48  2023 Week 48            30
# 1039  THA25C01  Passenger Journeys   2023W48  2023 Week 48            40
#
#                          Mode of Transport    UNIT      VALUE
# 0                         Dublin Metro Bus  Number  1987891.0
# 1              Bus, excluding Dublin Metro  Number   497598.0
# 2                                     Rail  Number        NaN
# 3     All public transport, excluding LUAS  Number  2485489.0
# 4                         Dublin Metro Bus  Number  2709579.0
# ...                                    ...     ...        ...
# 1035  All public transport, excluding LUAS  Number  5059620.0
# 1036                      Dublin Metro Bus  Number  3453532.0
# 1037           Bus, excluding Dublin Metro  Number   941393.0
# 1038                                  Rail  Number   942218.0
# 1039  All public transport, excluding LUAS  Number  5337143.0
#
# [1040 rows x 8 columns]

# %%
Dublin1 = London

# %%
Dublin1
# Out:
#     Period beginning  Bus journeys (m)  Underground journeys (m)  \
# 114           Jan-19             171.3                     106.7
# 115           Feb-19             171.3                     110.8
# 116           Mar-19             182.7                     114.1
# 117           Apr-19             156.6                     101.2
# 118           Apr-19             175.2                     106.1
# ..               ...               ...                       ...
# 172           Jun-23             147.1                      94.1
# 173           Jul-23             129.7                      86.6
# 174           Aug-23             139.6                      83.7
# 175           Sep-23             155.4                      93.4
# 176           Oct-23             146.4                      95.8
#
#      DLR Journeys (m)  Tram Journeys (m)
# 114               9.3                2.2
# 115               9.7                2.2
# 116              10.0                2.2
# 117               8.9                2.0
# 118               9.7                2.2
# ..                ...                ...
# 172               7.9                1.6
# 173               7.2                1.4
# 174               7.3                1.7
# 175               8.3                1.6
# 176               7.8                1.3
#
# [63 rows x 5 columns]

# %%
Dublin1 = Dublin1.iloc[114:,:]

# %%
Dublin1
# Out:
# Empty DataFrame
# Columns: [Period beginning, Bus journeys (m), Underground journeys (m), DLR Journeys (m), Tram Journeys (m)]
# Index: []

# %%
London.head(60)
# Out:
#     Period beginning  Bus journeys (m)  Underground journeys (m)  \
# 114           Jan-19             171.3                     106.7
# 115           Feb-19             171.3                     110.8
# 116           Mar-19             182.7                     114.1
# 117           Apr-19             156.6                     101.2
# 118           Apr-19             175.2                     106.1
# 119           May-19             171.4                     108.0
# 120           Jun-19             177.0                     111.7
# 121           Jul-19             149.8                     103.0
# 122           Aug-19             159.8                      99.4
# 123           Sep-19             179.3                     112.2
# 124           Oct-19             168.9                     113.3
# 125           Nov-19             176.2                     117.5
# 126           Dec-19             141.0                      91.2
# 127           Jan-20             169.4                     105.8
# 128           Feb-20             165.2                     106.2
# 129           Mar-20             126.4                      60.9
# 130           Apr-20              30.2                       5.7
# 131           May-20              32.5                       6.7
# 132           May-20              47.0                      13.3
# 133           Jun-20              66.7                      22.2
# 134           Jul-20              75.2                      28.8
# 135           Aug-20              94.8                      36.3
# 136           Sep-20             102.0                      39.5
# 137           Oct-20              88.9                      33.7
# 138           Nov-20              89.0                      32.1
# 139           Dec-20              57.5                      18.8
# 140           Jan-21              51.6                      16.8
# 141           Feb-21              56.9                      19.8
# 142           Mar-21              72.9                      22.4
# 143           Apr-21              95.9                      37.4
# 144           May-21             104.3                      42.5
# 145           May-21             107.0                      48.6
# 146           Jun-21             109.1                      49.6
# 147           Jul-21              98.8                      51.6
# 148           Aug-21             115.5                      58.2
# 149           Sep-21             130.2                      69.7
# 150           Oct-21             125.4                      73.7
# 151           Nov-21             131.3                      75.8
# 152           Dec-21              95.1                      45.4
# 153           Jan-22             123.5                      60.2
# 154           Feb-22             127.8                      65.4
# 155           Mar-22             126.7                      70.4
# 156           Apr-22             135.0                      79.2
# 157           May-22             140.5                      80.1
# 158           May-22             138.0                      71.7
# 159           Jun-22             137.8                      81.3
# 160           Jul-22             122.5                      73.9
# 161           Aug-22             132.9                      79.6
# 162           Sep-22             147.0                      88.2
# 163           Oct-22             143.1                      87.6
# 164           Nov-22             146.0                      95.1
# 165           Dec-22             116.9                      68.5
# 166           Jan-23             141.3                      85.2
# 167           Feb-23             141.6                      89.8
# 168           Mar-23             142.2                      84.9
# 169           Apr-23             140.9                      91.5
# 170           Apr-23             146.0                      88.2
# 171           May-23             145.8                      90.2
# 172           Jun-23             147.1                      94.1
# 173           Jul-23             129.7                      86.6
#
#      DLR Journeys (m)  Tram Journeys (m)
# 114               9.3                2.2
# 115               9.7                2.2
# 116              10.0                2.2
# 117               8.9                2.0
# 118               9.7                2.2
# 119               9.3                2.2
# 120               9.6                2.3
# 121               9.1                2.0
# 122               8.7                1.6
# 123               9.5                2.3
# 124              10.0                2.2
# 125               9.8                2.3
# 126               7.5                1.9
# 127               9.2                2.3
# 128               9.3                2.2
# 129               6.1                1.6
# 130               1.2                0.4
# 131               1.4                0.5
# 132               2.1                0.7
# 133               2.9                1.0
# 134               3.6                1.0
# 135               4.2                1.2
# 136               4.5                1.4
# 137               4.1                1.0
# 138               4.0                1.1
# 139               2.7                0.7
# 140               2.7                0.7
# 141               3.1                0.8
# 142               3.3                1.0
# 143               4.9                1.3
# 144               5.0                1.5
# 145               5.6                1.5
# 146               5.4                1.5
# 147               5.5                1.3
# 148               5.9                1.2
# 149               7.1                1.7
# 150               7.2                1.7
# 151               7.0                1.6
# 152               4.6                1.2
# 153               5.9                1.6
# 154               6.5                1.4
# 155               6.6                1.5
# 156               7.1                1.6
# 157               7.6                1.8
# 158               6.7                1.7
# 159               6.5                1.5
# 160               6.4                1.5
# 161               6.5                1.5
# 162               7.6                1.6
# 163               7.7                1.7
# 164               7.6                1.6
# 165               5.7                1.3
# 166               7.4                1.8
# 167               7.8                1.6
# 168               7.6                1.7
# 169               8.2                1.4
# 170               7.7                1.6
# 171               7.9                1.7
# 172               7.9                1.6
# 173               7.2                1.4

# %%
London2 = London

London2['Period beginning'] = London2['Period beginning'].str.slice(4)
London2
#London2019 = London2.loc[London2["Period beginning"]  == 19]

#London2019 
#London2020
London2.dtypes#London2021
#London2022
# Out:
# Period beginning             object
# Bus journeys (m)            float64
# Underground journeys (m)    float64
# DLR Journeys (m)            float64
# Tram Journeys (m)           float64
# dtype: object

# %%
#London2.dtypes



London2019 = London2.loc[London2['Period beginning'] =="19"]
London2020 = London2.loc[London2['Period beginning'] =="20"]
London2021 = London2.loc[London2['Period beginning'] =="21"]
London2022 = London2.loc[London2['Period beginning'] =="22"]

# %%
London2019.describe()
# Out:
#        Bus journeys (m)  Underground journeys (m)  DLR Journeys (m)  \
# count         13.000000                 13.000000         13.000000
# mean         167.730769                107.323077          9.315385
# std           12.364289                  7.196661          0.675581
# min          141.000000                 91.200000          7.500000
# 25%          159.800000                103.000000          9.100000
# 50%          171.300000                108.000000          9.500000
# 75%          176.200000                112.200000          9.700000
# max          182.700000                117.500000         10.000000
#
#        Tram Journeys (m)
# count          13.000000
# mean            2.123077
# std             0.200640
# min             1.600000
# 25%             2.000000
# 50%             2.200000
# 75%             2.200000
# max             2.300000

# %%
London2020.describe()
# Out:
#        Bus journeys (m)  Underground journeys (m)  DLR Journeys (m)  \
# count         13.000000                 13.000000         13.000000
# mean          88.061538                 39.230769          4.253846
# std           44.678696                 33.099884          2.586380
# min           30.200000                  5.700000          1.200000
# 25%           57.500000                 18.800000          2.700000
# 50%           88.900000                 32.100000          4.000000
# 75%          102.000000                 39.500000          4.500000
# max          169.400000                106.200000          9.300000
#
#        Tram Journeys (m)
# count          13.000000
# mean            1.161538
# std             0.588130
# min             0.400000
# 25%             0.700000
# 50%             1.000000
# 75%             1.400000
# max             2.300000

# %%
London2021.describe()
# Out:
#        Bus journeys (m)  Underground journeys (m)  DLR Journeys (m)  \
# count         13.000000                 13.000000         13.000000
# mean          99.538462                 47.038462          5.176923
# std           25.660460                 19.548083          1.482764
# min           51.600000                 16.800000          2.700000
# 25%           95.100000                 37.400000          4.600000
# 50%          104.300000                 48.600000          5.400000
# 75%          115.500000                 58.200000          5.900000
# max          131.300000                 75.800000          7.200000
#
#        Tram Journeys (m)
# count          13.000000
# mean            1.307692
# std             0.322649
# min             0.700000
# 25%             1.200000
# 50%             1.300000
# 75%             1.500000
# max             1.700000

# %%
London2022.describe()
# Out:
#        Bus journeys (m)  Underground journeys (m)  DLR Journeys (m)  \
# count         13.000000                 13.000000         13.000000
# mean         133.669231                 77.015385          6.800000
# std            9.556532                  9.897040          0.665833
# min          116.900000                 60.200000          5.700000
# 25%          126.700000                 70.400000          6.500000
# 50%          135.000000                 79.200000          6.600000
# 75%          140.500000                 81.300000          7.600000
# max          147.000000                 95.100000          7.700000
#
#        Tram Journeys (m)
# count          13.000000
# mean            1.561538
# std             0.132530
# min             1.300000
# 25%             1.500000
# 50%             1.600000
# 75%             1.600000
# max             1.800000

# %%
#London20222 = London2022[['Bus journeys (m)']].mean(axis=1)
London20222 = London2022.loc[:, 'Bus journeys (m)'].mean().round(2)
London20222
# Out:
# 133.67

# %%
L2019BusMean = London2019.loc[:, 'Bus journeys (m)'].mean().round(2)
L2019UndergroundMean = London2019.loc[:, 'Underground journeys (m)'].mean().round(2)
L2019DLRMean = London2019.loc[:, 'DLR Journeys (m)'].mean().round(2)
L2019TramMean = London2019.loc[:, 'Tram Journeys (m)'].mean().round(2)

L2020BusMean = London2020.loc[:, 'Bus journeys (m)'].mean().round(2)
L2020UndergroundMean = London2020.loc[:, 'Underground journeys (m)'].mean().round(2)
L2020DLRMean = London2020.loc[:, 'DLR Journeys (m)'].mean().round(2)
L2020TramMean = London2020.loc[:, 'Tram Journeys (m)'].mean().round(2)

L2021BusMean = London2021.loc[:, 'Bus journeys (m)'].mean().round(2)
L2021UndergroundMean = London2021.loc[:, 'Underground journeys (m)'].mean().round(2)
L2021DLRMean = London2021.loc[:, 'DLR Journeys (m)'].mean().round(2)
L2021TramMean = London2021.loc[:, 'Tram Journeys (m)'].mean().round(2)

L2022BusMean = London2022.loc[:, 'Bus journeys (m)'].mean().round(2)
L2022UndergroundMean = London2022.loc[:, 'Underground journeys (m)'].mean().round(2)
L2022DLRMean = London2022.loc[:, 'DLR Journeys (m)'].mean().round(2)
L2022TramMean = London2022.loc[:, 'Tram Journeys (m)'].mean().round(2)

# %% [markdown]
# Get mean of 2019-2022 of 3 countries and put it as a proportion of population the graph 3 lines for 4 years with percentage proportion in a line graph. have colours as national colours to make it more readable.

# %%
Australia
# Out:
#       Year  Month Month name Metropolitan train Metropolitan tram  \
# 0   2018.0    1.0    January         16,809,932        15,231,368
# 1   2018.0    2.0   February         19,554,477        16,980,925
# 2   2018.0    3.0      March         22,659,010        19,832,126
# 3   2018.0    4.0      April         20,312,040        16,919,872
# 4   2018.0    5.0        May         22,768,447        17,691,427
# ..     ...    ...        ...                ...               ...
# 66  2023.0    7.0       July         14,020,167        12,335,062
# 67  2023.0    8.0     August         16,437,412        13,280,460
# 68  2023.0    9.0  September         14,847,177        12,149,257
# 69  2023.0   10.0    October         15,199,277        12,453,509
# 70  2023.0   11.0   November         14,653,512        12,491,341
#
#    Metropolitan bus Regional train Regional coach Regional bus
# 0         7,568,547      1,466,256        116,568      721,229
# 1        10,487,311      1,522,981        103,197    1,118,494
# 2        11,528,895      1,809,774        117,180    1,224,816
# 3         9,592,750      1,684,827        107,480      946,218
# 4        11,263,486      1,790,656        109,456    1,258,704
# ..              ...            ...            ...          ...
# 66        9,219,892      1,846,565         99,755    1,148,259
# 67       10,304,037      1,807,251         98,413    1,255,113
# 68        9,260,131      1,775,964        100,982    1,103,635
# 69       10,083,249      1,849,701        106,717    1,242,909
# 70        9,872,183      1,808,656        104,648    1,190,730
#
# [71 rows x 9 columns]

# %%
Australia = Australia.iloc[12:]
#Australia.drop(Australia.tail(10).index,
        #inplace = True)
Australia.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10372\4133136188.py in ?()
#       1 Australia = Australia.iloc[12:]
#       2 #Australia.drop(Australia.tail(10).index,
#       3         #inplace = True)
# ----> 4 Australia.column
#
# ~\anaconda3\envs\notebook\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
column_headers = list(Australia.columns.values)
print("The Column Header :", column_headers)
# Out:
# The Column Header : ['Year', 'Month', 'Month name', 'Metropolitan train', 'Metropolitan tram', 'Metropolitan bus', 'Regional train', 'Regional coach', 'Regional bus']

# %%
Australia2019 = Australia.loc[Australia['Year'] ==2019.0]
Australia2020 = Australia.loc[Australia['Year'] ==2020.0]
Australia2021 = Australia.loc[Australia['Year'] ==2021.0]
Australia2022 = Australia.loc[Australia['Year'] ==2022.0]

# %%
#Australia.dtypes
Australia.replace(',','', regex=True, inplace=True)
#Australia['Metropolitan train'] = Australia['Metropolitan train'].astype(int)
#removing comma to make string into int
# Out:
# C:\Users\leega\AppData\Local\Temp\ipykernel_10372\2790097635.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Australia.replace(',','', regex=True, inplace=True)

# %%
Australia['Metropolitan train'] = Australia['Metropolitan train'].astype(int)
Australia['Metropolitan tram'] = Australia['Metropolitan tram'].astype(int)
Australia['Metropolitan bus'] = Australia['Metropolitan bus'].astype(int)
Australia['Regional train'] = Australia['Regional train'].astype(int)
Australia['Regional coach'] = Australia['Regional coach'].astype(int)
Australia['Regional bus'] = Australia['Regional bus'].astype(int)
# Out:
# C:\Users\leega\AppData\Local\Temp\ipykernel_10372\1964807782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Australia['Metropolitan train'] = Australia['Metropolitan train'].astype(int)
# C:\Users\leega\AppData\Local\Temp\ipykernel_10372\1964807782.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Australia['Metropolitan tram'] = Australia['Metropolitan tram'].astype(int)
# C:\Users\leega\AppData\Local\Temp\ipykernel_10372\1964807782.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Australia['Metropolitan bus'] = Australia['Metropolitan bus'].astype(int)
# C:\Users\leega\AppData\Local\Temp\ipykernel_10372\1964807782.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Australia['Regional train'] = Australia['Regional train'].astype(int)
# C:\Users\leega\AppData\Local\Temp\ipykernel_10372\1964807782.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Australia['Regional coach'] = Australia['Regional coach'].astype(int)
# C:\Users\leega\AppData\Local\Temp\ipykernel_10372\1964807782.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Australia['Regional bus'] = Australia['Regional bus'].astype(int)

# %%
Australia2019 = Australia.loc[Australia['Year'] ==2019.0]
Australia2020 = Australia.loc[Australia['Year'] ==2020.0]
Australia2021 = Australia.loc[Australia['Year'] ==2021.0]
Australia2022 = Australia.loc[Australia['Year'] ==2022.0]

# %%
Australia.dtypes
Australia2019
# Out:
#       Year  Month Month name  Metropolitan train  Metropolitan tram  \
# 12  2019.0    1.0    January            17074623           15695535
# 13  2019.0    2.0   February            20011823           16485000
# 14  2019.0    3.0      March            22250796           19456794
# 15  2019.0    4.0      April            18579825           17400302
# 16  2019.0    5.0        May            23045436           18410816
# 17  2019.0    6.0       June            19099513           15041547
# 18  2019.0    7.0       July            20771347           16784796
# 19  2019.0    8.0     August            22618021           17578879
# 20  2019.0    9.0  September            20593343           15733247
# 21  2019.0   10.0    October            22429337           16917616
# 22  2019.0   11.0   November            20413342           15344062
# 23  2019.0   12.0   December            17890229           13736921
#
#     Metropolitan bus  Regional train  Regional coach  Regional bus
# 12           7845144         1532342          110708        748369
# 13          10105546         1676391          103886       1201991
# 14          11775566         1916630          112302       1232933
# 15           9667587         1722745          111012        961318
# 16          12082141         2007166          111604       1287180
# 17           9515676         1704331           98137       1084632
# 18          10417277         1898701          108706       1083306
# 19          11485155         1981136          107987       1275349
# 20          10238956         1805116          104419       1089826
# 21          11294945         1927784          115819       1212228
# 22          10405336         1728907          106782       1126220
# 23           8858522         1648394          110447        873469

# %%
A2019BusMean = (Australia2019.loc[:, 'Metropolitan bus'].mean() + Australia2019.loc[:, 'Regional bus'].mean() + Australia2019.loc[:, 'Regional coach'].mean()).round(2)
A2019Train = (Australia2019.loc[:, 'Metropolitan train'].mean() + Australia2019.loc[:, 'Regional train'].mean()).round(2)
A2019Tram = Australia2019.loc[:, 'Metropolitan tram'].mean().round(2) 

A2020BusMean = (Australia2020.loc[:, 'Metropolitan bus'].mean() + Australia2020.loc[:, 'Regional bus'].mean() + Australia2020.loc[:, 'Regional coach'].mean()).round(2)
A2020Train = (Australia2020.loc[:, 'Metropolitan train'].mean() + Australia2020.loc[:, 'Regional train'].mean()).round(2)
A2020Tram = Australia2020.loc[:, 'Metropolitan tram'].mean().round(2) 

A2021BusMean = (Australia2021.loc[:, 'Metropolitan bus'].mean() + Australia2021.loc[:, 'Regional bus'].mean() + Australia2021.loc[:, 'Regional coach'].mean()).round()
A2021Train = (Australia2021.loc[:, 'Metropolitan train'].mean() + Australia2021.loc[:, 'Regional train'].mean()).round()
A2021Tram = Australia2021.loc[:, 'Metropolitan tram'].mean().round(2) 

A2022BusMean = (Australia2022.loc[:, 'Metropolitan bus'].mean() + Australia2022.loc[:, 'Regional bus'].mean() + Australia2022.loc[:, 'Regional coach'].mean()).round(2)
A2022Train = (Australia2022.loc[:, 'Metropolitan train'].mean() + Australia2022.loc[:, 'Regional train'].mean()).round(2)
A2022Tram = Australia2022.loc[:, 'Metropolitan tram'].mean().round(2)

# %%
L2019TramMean
# Out:
# 2.12

# %%
DublinBus
# Out:
#      STATISTIC     Statistic Label  TLIST(A1)  Year  C03935V04687  \
# 0     THA24C01  Passenger Journeys       2019  2019            10
# 1     THA24C01  Passenger Journeys       2019  2019            10
# 2     THA24C01  Passenger Journeys       2019  2019            10
# 3     THA24C01  Passenger Journeys       2019  2019            10
# 4     THA24C01  Passenger Journeys       2019  2019            10
# ...        ...                 ...        ...   ...           ...
# 1055  THA24C01  Passenger Journeys       2023  2023            40
# 1056  THA24C01  Passenger Journeys       2023  2023            40
# 1057  THA24C01  Passenger Journeys       2023  2023            40
# 1058  THA24C01  Passenger Journeys       2023  2023            40
# 1059  THA24C01  Passenger Journeys       2023  2023            40
#
#                          Mode of Transport  C01198V01436 Weeks of the year  \
# 0                         Dublin Metro Bus             1           Week 01
# 1                         Dublin Metro Bus             2           Week 02
# 2                         Dublin Metro Bus             3           Week 03
# 3                         Dublin Metro Bus             4           Week 04
# 4                         Dublin Metro Bus             5           Week 05
# ...                                    ...           ...               ...
# 1055  All public transport, excluding LUAS            49           Week 49
# 1056  All public transport, excluding LUAS            50           Week 50
# 1057  All public transport, excluding LUAS            51           Week 51
# 1058  All public transport, excluding LUAS            52           Week 52
# 1059  All public transport, excluding LUAS            53           Week 53
#
#         UNIT      VALUE
# 0     Number  1987891.0
# 1     Number  2709579.0
# 2     Number  2784678.0
# 3     Number  2858346.0
# 4     Number  2924821.0
# ...      ...        ...
# 1055  Number        NaN
# 1056  Number        NaN
# 1057  Number        NaN
# 1058  Number        NaN
# 1059  Number        NaN
#
# [1060 rows x 10 columns]

# %%
DublinBus2
# Out:
#      STATISTIC     Statistic Label  TLIST(A1)  Year  C03935V04687  \
# 0     THA24C01  Passenger Journeys       2019  2019            10
# 1     THA24C01  Passenger Journeys       2019  2019            10
# 2     THA24C01  Passenger Journeys       2019  2019            10
# 3     THA24C01  Passenger Journeys       2019  2019            10
# 4     THA24C01  Passenger Journeys       2019  2019            10
# ...        ...                 ...        ...   ...           ...
# 1055  THA24C01  Passenger Journeys       2023  2023            40
# 1056  THA24C01  Passenger Journeys       2023  2023            40
# 1057  THA24C01  Passenger Journeys       2023  2023            40
# 1058  THA24C01  Passenger Journeys       2023  2023            40
# 1059  THA24C01  Passenger Journeys       2023  2023            40
#
#                          Mode of Transport  C01198V01436 Weeks of the year  \
# 0                         Dublin Metro Bus             1           Week 01
# 1                         Dublin Metro Bus             2           Week 02
# 2                         Dublin Metro Bus             3           Week 03
# 3                         Dublin Metro Bus             4           Week 04
# 4                         Dublin Metro Bus             5           Week 05
# ...                                    ...           ...               ...
# 1055  All public transport, excluding LUAS            49           Week 49
# 1056  All public transport, excluding LUAS            50           Week 50
# 1057  All public transport, excluding LUAS            51           Week 51
# 1058  All public transport, excluding LUAS            52           Week 52
# 1059  All public transport, excluding LUAS            53           Week 53
#
#         UNIT      VALUE
# 0     Number  1987891.0
# 1     Number  2709579.0
# 2     Number  2784678.0
# 3     Number  2858346.0
# 4     Number  2924821.0
# ...      ...        ...
# 1055  Number        NaN
# 1056  Number        NaN
# 1057  Number        NaN
# 1058  Number        NaN
# 1059  Number        NaN
#
# [1060 rows x 10 columns]

# %%
DublinRail
# Out:
#      STATISTIC     Statistic Label TLIST(W1)          Week  C03935V04687  \
# 0     THA25C01  Passenger Journeys   2019W01  2019 Week 01            10
# 1     THA25C01  Passenger Journeys   2019W01  2019 Week 01            20
# 2     THA25C01  Passenger Journeys   2019W01  2019 Week 01            30
# 3     THA25C01  Passenger Journeys   2019W01  2019 Week 01            40
# 4     THA25C01  Passenger Journeys   2019W02  2019 Week 02            10
# ...        ...                 ...       ...           ...           ...
# 1035  THA25C01  Passenger Journeys   2023W47  2023 Week 47            40
# 1036  THA25C01  Passenger Journeys   2023W48  2023 Week 48            10
# 1037  THA25C01  Passenger Journeys   2023W48  2023 Week 48            20
# 1038  THA25C01  Passenger Journeys   2023W48  2023 Week 48            30
# 1039  THA25C01  Passenger Journeys   2023W48  2023 Week 48            40
#
#                          Mode of Transport    UNIT      VALUE
# 0                         Dublin Metro Bus  Number  1987891.0
# 1              Bus, excluding Dublin Metro  Number   497598.0
# 2                                     Rail  Number        NaN
# 3     All public transport, excluding LUAS  Number  2485489.0
# 4                         Dublin Metro Bus  Number  2709579.0
# ...                                    ...     ...        ...
# 1035  All public transport, excluding LUAS  Number  5059620.0
# 1036                      Dublin Metro Bus  Number  3453532.0
# 1037           Bus, excluding Dublin Metro  Number   941393.0
# 1038                                  Rail  Number   942218.0
# 1039  All public transport, excluding LUAS  Number  5337143.0
#
# [1040 rows x 8 columns]

# %%
DublinLuas = DublinLuas[ DublinLuas[ 'Statistic Label' ].str.contains('All Luas lines')==True ]
DublinLuas = DublinLuas[ DublinLuas[ 'Month' ].str.contains('All months')==False ]

DublinLuas.head()
# Out:
#     STATISTIC Statistic Label  TLIST(A1)  Year C01885V02316     Month    UNIT  \
# 130  TOA11C03  All Luas lines       2018  2018           01   January  Number
# 131  TOA11C03  All Luas lines       2018  2018           02  February  Number
# 132  TOA11C03  All Luas lines       2018  2018           03     March  Number
# 133  TOA11C03  All Luas lines       2018  2018           04     April  Number
# 134  TOA11C03  All Luas lines       2018  2018           05       May  Number
#
#        VALUE
# 130  3218649
# 131  3118289
# 132  3097570
# 133  3350056
# 134  3622338

# %%
Dublin2019 = DublinLuas.loc[DublinLuas['Year'] ==2019]
Dublin2020 = DublinLuas.loc[DublinLuas['Year'] ==2020]
Dublin2021 = DublinLuas.loc[DublinLuas['Year'] ==2021]
Dublin2022 = DublinLuas.loc[DublinLuas['Year'] ==2022]


D2019TramMean = Dublin2019.loc[:, 'VALUE'].mean().round(2)
D2020TramMean = Dublin2020.loc[:, 'VALUE'].mean().round(2)
D2021TramMean = Dublin2021.loc[:, 'VALUE'].mean().round(2)
D2022TramMean = Dublin2022.loc[:, 'VALUE'].mean().round(2)

# %%
D2019TramMean, D2020TramMean, D2021TramMean, D2022TramMean,L2019TramMean, A2019Tram
# Out:
# (4028935.92, 1598004.67, 1623443.25, 3222322.92, 2.12, 16548792.92)

# %%
#getting a proportion of the public transport mean against yearly population of the area

# %%
D2019pop = (D2019TramMean/1215000*25357170).round(2)
D2020pop = (D2020TramMean/1228000*25670051).round(2)
D2021pop = (D2021TramMean/1242000*25921089).round(2)
D2022pop = (D2022TramMean/1256000*26177413).round(2)

A2019pop = (A2019Tram).round(2)
A2020pop = (A2020Tram).round(2)
A2021pop = (A2021Tram).round(2)
A2022pop = (A2022Tram).round(2)

L2019pop = (L2019TramMean/9.177000*25357170).round(2)
L2020pop = (L2020TramMean/9.304000*25670051).round(2)
L2021pop = (L2021TramMean/9.426000*25921089).round(2)
L2022pop = (L2022TramMean/9.541000*26177413).round(2)

#values for london in (m) need to divide with decimal

# %%
D2019pop, A2019pop, L2019pop
# Out:
# (84084290.57, 16548792.92, 5857818.5)

# %%
D2019TramMean
# Out:
# 4028935.92

# %%
x=["2019","2020","2021","2022"]
y1=[D2019TramMean,D2020TramMean,D2021TramMean,D2022TramMean]
y2=[L2019TramMean*1000000,L2020TramMean*1000000,L2021TramMean*1000000,L2022TramMean*1000000]
y3=[A2019Tram,A2020Tram,A2021Tram,A2022Tram]

plt.plot(x, y1, label ='Dublin')
plt.plot(x, y2,  label ='London')
plt.plot(x, y3,  label ='Australia')

plt.xlabel("Year")
plt.ylabel("Mean in millions")
plt.legend()
plt.title('multiple plots')
plt.show()

# %%
x=["2019","2020","2021","2022"]
y1=[D2019pop,D2020pop,D2021pop,D2022pop]
y2=[L2019pop,L2020pop,L2021pop,L2022pop]
y3=[A2019pop,A2020pop,A2021pop,A2022pop]

plt.plot(x, y1, label ='Dublin')
plt.plot(x, y2,  label ='London')
plt.plot(x, y3,  label ='Australia')

plt.xlabel("Year")
plt.ylabel("bus mean relative to population")
plt.legend()
plt.title('multiple plots')
plt.show()

# %%
L2019pop
# Out:
# 5857818.5

# %%
x=["2019","2020","2021","2022"]
y1=[D2019pop,D2020pop,D2021pop,D2022pop]
y2=[L2019pop,L2020pop,L2021pop,L2022pop]
y3=[A2019pop,A2020pop,A2021pop,A2022pop]

plt.plot(x, y1, label ='Dublin')
plt.plot(x, y2,  label ='London')
plt.plot(x, y3,  label ='Australia')

plt.xlabel("Year")
plt.ylabel("Meanrelative to population")
plt.legend()
plt.title('multiple plots')
plt.show()

# %%
data = London2019['Tram Journeys (m)']
data
# Out:
# 114    2.2
# 115    2.2
# 116    2.2
# 117    2.0
# 118    2.2
# 119    2.2
# 120    2.3
# 121    2.0
# 122    1.6
# 123    2.3
# 124    2.2
# 125    2.3
# 126    1.9
# Name: Tram Journeys (m), dtype: float64

# %%
import scipy.stats as st
import numpy as np

#confidence interval London 2019
data1 = [2.2, 2.2, 2.2, 2.0, 2.2, 2.2, 2.3, 2.0, 1.6, 2.3, 2.2, 2.3, 1.9]

#create 95% confidence interval for population mean of London 2019
st.t.interval(0.95, len(data1)-1, loc=np.mean(data1), scale=st.sem(data1))


#(16.758, 24.042)
# Out:
# (2.0018313835438613, 2.244322462609985)

# %%
London2019
# Out:
#     Period beginning  Bus journeys (m)  Underground journeys (m)  \
# 114               19             171.3                     106.7
# 115               19             171.3                     110.8
# 116               19             182.7                     114.1
# 117               19             156.6                     101.2
# 118               19             175.2                     106.1
# 119               19             171.4                     108.0
# 120               19             177.0                     111.7
# 121               19             149.8                     103.0
# 122               19             159.8                      99.4
# 123               19             179.3                     112.2
# 124               19             168.9                     113.3
# 125               19             176.2                     117.5
# 126               19             141.0                      91.2
#
#      DLR Journeys (m)  Tram Journeys (m)
# 114               9.3                2.2
# 115               9.7                2.2
# 116              10.0                2.2
# 117               8.9                2.0
# 118               9.7                2.2
# 119               9.3                2.2
# 120               9.6                2.3
# 121               9.1                2.0
# 122               8.7                1.6
# 123               9.5                2.3
# 124              10.0                2.2
# 125               9.8                2.3
# 126               7.5                1.9

# %%
Dublin2019
# Out:
#     STATISTIC Statistic Label  TLIST(A1)  Year C01885V02316      Month  \
# 143  TOA11C03  All Luas lines       2019  2019           01    January
# 144  TOA11C03  All Luas lines       2019  2019           02   February
# 145  TOA11C03  All Luas lines       2019  2019           03      March
# 146  TOA11C03  All Luas lines       2019  2019           04      April
# 147  TOA11C03  All Luas lines       2019  2019           05        May
# 148  TOA11C03  All Luas lines       2019  2019           06       June
# 149  TOA11C03  All Luas lines       2019  2019           07       July
# 150  TOA11C03  All Luas lines       2019  2019           08     August
# 151  TOA11C03  All Luas lines       2019  2019           09  September
# 152  TOA11C03  All Luas lines       2019  2019           10    October
# 153  TOA11C03  All Luas lines       2019  2019           11   November
# 154  TOA11C03  All Luas lines       2019  2019           12   December
#
#        UNIT    VALUE
# 143  Number  3658484
# 144  Number  3727609
# 145  Number  4069124
# 146  Number  3826763
# 147  Number  4003472
# 148  Number  3750724
# 149  Number  4130610
# 150  Number  3781395
# 151  Number  4166802
# 152  Number  4502319
# 153  Number  4496717
# 154  Number  4233212

# %%
#confidence interval Dublin 2019
data2 = [3.7, 3.7, 4.1, 3.8, 4.0, 3.8, 4.1, 3.8, 4.2, 4.5, 4.5, 4.2]

#create 95% confidence interval for population mean of London 2019
st.t.interval(0.95, len(data2)-1, loc=np.mean(data2), scale=st.sem(data2))
# Out:
# (3.8529442134176355, 4.213722453249033)

# %%
Australia2019
# Out:
#       Year  Month Month name  Metropolitan train  Metropolitan tram  \
# 12  2019.0    1.0    January            17074623           15695535
# 13  2019.0    2.0   February            20011823           16485000
# 14  2019.0    3.0      March            22250796           19456794
# 15  2019.0    4.0      April            18579825           17400302
# 16  2019.0    5.0        May            23045436           18410816
# 17  2019.0    6.0       June            19099513           15041547
# 18  2019.0    7.0       July            20771347           16784796
# 19  2019.0    8.0     August            22618021           17578879
# 20  2019.0    9.0  September            20593343           15733247
# 21  2019.0   10.0    October            22429337           16917616
# 22  2019.0   11.0   November            20413342           15344062
# 23  2019.0   12.0   December            17890229           13736921
#
#     Metropolitan bus  Regional train  Regional coach  Regional bus
# 12           7845144         1532342          110708        748369
# 13          10105546         1676391          103886       1201991
# 14          11775566         1916630          112302       1232933
# 15           9667587         1722745          111012        961318
# 16          12082141         2007166          111604       1287180
# 17           9515676         1704331           98137       1084632
# 18          10417277         1898701          108706       1083306
# 19          11485155         1981136          107987       1275349
# 20          10238956         1805116          104419       1089826
# 21          11294945         1927784          115819       1212228
# 22          10405336         1728907          106782       1126220
# 23           8858522         1648394          110447        873469

# %%
#confidence interval Australia 2019
data3 = [15.7, 16.5, 19.5, 17.4, 18.4, 15.0, 16.8, 17.6, 15.7, 16.9, 15.3, 13.7]

#create 95% confidence interval for population mean of London 2019
st.t.interval(0.95, len(data3)-1, loc=np.mean(data3), scale=st.sem(data3))
# Out:
# (15.533973790256175, 17.54935954307716)

# %%
import scipy
from scipy.stats import ttest_ind
scipy.stats.ttest_ind(Australia2019['Metropolitan tram'], London2019['Tram Journeys (m)'], equal_var=False)
# Out:
# TtestResult(statistic=36.63930020022628, pvalue=7.544556780329852e-13, df=11.00000000000033)

# %%
 scipy.stats.ttest_ind( Dublin2019['VALUE'], London2019['Tram Journeys (m)'], equal_var=False)
# Out:
# TtestResult(statistic=48.15933801697137, pvalue=3.794270299047897e-14, df=11.000000000009733)

# %%
 scipy.stats.ttest_ind( Dublin2019['VALUE'], Australia2019['Metropolitan tram'], equal_var=False)
# Out:
# TtestResult(statistic=-27.2555888292569, pvalue=5.466334041849475e-12, df=11.753863795893373)

# %%
#Anova not ideal as we have the full population statistics and this is used for sample populations generally


from scipy.stats import f_oneway

#ANOVA test for tram means year on year
A19 = Australia2019["Metropolitan tram"]
D19 = Dublin2019["VALUE"]
L19 = London2019["Tram Journeys (m)"]

statistic, p_value = f_oneway(D19, A19, L19)

print(f"One-way ANOVA Statistic: {statistic}")
print(f"P-value: {p_value}")

if p_value < 0.05:
    print("Reject null hypothesis as there is a significant difference between the 3 different countries")
else:
    print("Accept null hypothesis")
# Out:
# One-way ANOVA Statistic: 1118.8811954598161
# P-value: 9.483577464976757e-32
# Reject null hypothesis as there is a significant difference between the 3 different countries

# %%
London2019.head()
Dublin2019.head()
Australia2019.head()
DublinBus.head()
DublinRail.tail()
# Out:
#      STATISTIC     Statistic Label TLIST(W1)          Week  C03935V04687  \
# 1035  THA25C01  Passenger Journeys   2023W47  2023 Week 47            40
# 1036  THA25C01  Passenger Journeys   2023W48  2023 Week 48            10
# 1037  THA25C01  Passenger Journeys   2023W48  2023 Week 48            20
# 1038  THA25C01  Passenger Journeys   2023W48  2023 Week 48            30
# 1039  THA25C01  Passenger Journeys   2023W48  2023 Week 48            40
#
#                          Mode of Transport    UNIT      VALUE
# 1035  All public transport, excluding LUAS  Number  5059620.0
# 1036                      Dublin Metro Bus  Number  3453532.0
# 1037           Bus, excluding Dublin Metro  Number   941393.0
# 1038                                  Rail  Number   942218.0
# 1039  All public transport, excluding LUAS  Number  5337143.0

# %%
DB = DublinBus[DublinBus["Mode of Transport"].str.contains("Dublin Metro Bus") == True]

DublinBus2019 = DB[DB["Year"] == 2019]
DublinBus2020 = DB[DB["Year"] == 2020]
DublinBus2021 = DB[DB["Year"] == 2021]
DublinBus2022 = DB[DB["Year"] == 2022]
#DublinBus2021.tail()
                         

DublinBus2019 = DublinBus2019.dropna()
DublinBus2020 = DublinBus2020.dropna()
DublinBus2021 = DublinBus2021.dropna()
DublinBus2022 = DublinBus2022.dropna()

DublinBus2022.tail()

#dropping week 53 as nan value for each year
# Out:
#     STATISTIC     Statistic Label  TLIST(A1)  Year  C03935V04687  \
# 683  THA24C01  Passenger Journeys       2022  2022            10
# 684  THA24C01  Passenger Journeys       2022  2022            10
# 685  THA24C01  Passenger Journeys       2022  2022            10
# 686  THA24C01  Passenger Journeys       2022  2022            10
# 687  THA24C01  Passenger Journeys       2022  2022            10
#
#     Mode of Transport  C01198V01436 Weeks of the year    UNIT      VALUE
# 683  Dublin Metro Bus            48           Week 48  Number  3147713.0
# 684  Dublin Metro Bus            49           Week 49  Number  3073856.0
# 685  Dublin Metro Bus            50           Week 50  Number  3050335.0
# 686  Dublin Metro Bus            51           Week 51  Number  2741688.0
# 687  Dublin Metro Bus            52           Week 52  Number  2840848.0

# %%
DublinRail.head()
# Out:
#   STATISTIC     Statistic Label TLIST(W1)          Week  C03935V04687  \
# 0  THA25C01  Passenger Journeys   2019W01  2019 Week 01            10
# 1  THA25C01  Passenger Journeys   2019W01  2019 Week 01            20
# 2  THA25C01  Passenger Journeys   2019W01  2019 Week 01            30
# 3  THA25C01  Passenger Journeys   2019W01  2019 Week 01            40
# 4  THA25C01  Passenger Journeys   2019W02  2019 Week 02            10
#
#                       Mode of Transport    UNIT      VALUE
# 0                      Dublin Metro Bus  Number  1987891.0
# 1           Bus, excluding Dublin Metro  Number   497598.0
# 2                                  Rail  Number        NaN
# 3  All public transport, excluding LUAS  Number  2485489.0
# 4                      Dublin Metro Bus  Number  2709579.0

# %%
DublinBus2["Mode of Transport"].unique()
# Out:
# array(['Dublin Metro Bus', 'Bus, excluding Dublin Metro', 'Rail',
#        'All public transport, excluding LUAS'], dtype=object)

# %%
DR = DublinBus2[DublinBus2["Mode of Transport"].str.contains("Rail") == True]

DublinRail2019 = DR[DR["Year"] == 2019]
DublinRail2020 = DR[DR["Year"] == 2020]
DublinRail2021 = DR[DR["Year"] == 2021]
DublinRail2022 = DR[DR["Year"] == 2022]
#DublinBus2021.tail()
                         

#DublinRail2019 = DublinRail2019.dropna()
#DublinRail2020 = DublinRail2020.dropna()
#DublinRail2021 = DublinRail2021.dropna()
#DublinRail2022 = DublinRail2022.dropna()

#DublinRail2022.tail()

#dropping week 53 as nan value for each year

# %%
DublinRail2019
# Out:
#     STATISTIC     Statistic Label  TLIST(A1)  Year  C03935V04687  \
# 106  THA24C01  Passenger Journeys       2019  2019            30
# 107  THA24C01  Passenger Journeys       2019  2019            30
# 108  THA24C01  Passenger Journeys       2019  2019            30
# 109  THA24C01  Passenger Journeys       2019  2019            30
# 110  THA24C01  Passenger Journeys       2019  2019            30
# 111  THA24C01  Passenger Journeys       2019  2019            30
# 112  THA24C01  Passenger Journeys       2019  2019            30
# 113  THA24C01  Passenger Journeys       2019  2019            30
# 114  THA24C01  Passenger Journeys       2019  2019            30
# 115  THA24C01  Passenger Journeys       2019  2019            30
# 116  THA24C01  Passenger Journeys       2019  2019            30
# 117  THA24C01  Passenger Journeys       2019  2019            30
# 118  THA24C01  Passenger Journeys       2019  2019            30
# 119  THA24C01  Passenger Journeys       2019  2019            30
# 120  THA24C01  Passenger Journeys       2019  2019            30
# 121  THA24C01  Passenger Journeys       2019  2019            30
# 122  THA24C01  Passenger Journeys       2019  2019            30
# 123  THA24C01  Passenger Journeys       2019  2019            30
# 124  THA24C01  Passenger Journeys       2019  2019            30
# 125  THA24C01  Passenger Journeys       2019  2019            30
# 126  THA24C01  Passenger Journeys       2019  2019            30
# 127  THA24C01  Passenger Journeys       2019  2019            30
# 128  THA24C01  Passenger Journeys       2019  2019            30
# 129  THA24C01  Passenger Journeys       2019  2019            30
# 130  THA24C01  Passenger Journeys       2019  2019            30
# 131  THA24C01  Passenger Journeys       2019  2019            30
# 132  THA24C01  Passenger Journeys       2019  2019            30
# 133  THA24C01  Passenger Journeys       2019  2019            30
# 134  THA24C01  Passenger Journeys       2019  2019            30
# 135  THA24C01  Passenger Journeys       2019  2019            30
# 136  THA24C01  Passenger Journeys       2019  2019            30
# 137  THA24C01  Passenger Journeys       2019  2019            30
# 138  THA24C01  Passenger Journeys       2019  2019            30
# 139  THA24C01  Passenger Journeys       2019  2019            30
# 140  THA24C01  Passenger Journeys       2019  2019            30
# 141  THA24C01  Passenger Journeys       2019  2019            30
# 142  THA24C01  Passenger Journeys       2019  2019            30
# 143  THA24C01  Passenger Journeys       2019  2019            30
# 144  THA24C01  Passenger Journeys       2019  2019            30
# 145  THA24C01  Passenger Journeys       2019  2019            30
# 146  THA24C01  Passenger Journeys       2019  2019            30
# 147  THA24C01  Passenger Journeys       2019  2019            30
# 148  THA24C01  Passenger Journeys       2019  2019            30
# 149  THA24C01  Passenger Journeys       2019  2019            30
# 150  THA24C01  Passenger Journeys       2019  2019            30
# 151  THA24C01  Passenger Journeys       2019  2019            30
# 152  THA24C01  Passenger Journeys       2019  2019            30
# 153  THA24C01  Passenger Journeys       2019  2019            30
# 154  THA24C01  Passenger Journeys       2019  2019            30
# 155  THA24C01  Passenger Journeys       2019  2019            30
# 156  THA24C01  Passenger Journeys       2019  2019            30
# 157  THA24C01  Passenger Journeys       2019  2019            30
# 158  THA24C01  Passenger Journeys       2019  2019            30
#
#     Mode of Transport  C01198V01436 Weeks of the year    UNIT  VALUE
# 106              Rail             1           Week 01  Number    NaN
# 107              Rail             2           Week 02  Number    NaN
# 108              Rail             3           Week 03  Number    NaN
# 109              Rail             4           Week 04  Number    NaN
# 110              Rail             5           Week 05  Number    NaN
# 111              Rail             6           Week 06  Number    NaN
# 112              Rail             7           Week 07  Number    NaN
# 113              Rail             8           Week 08  Number    NaN
# 114              Rail             9           Week 09  Number    NaN
# 115              Rail            10           Week 10  Number    NaN
# 116              Rail            11           Week 11  Number    NaN
# 117              Rail            12           Week 12  Number    NaN
# 118              Rail            13           Week 13  Number    NaN
# 119              Rail            14           Week 14  Number    NaN
# 120              Rail            15           Week 15  Number    NaN
# 121              Rail            16           Week 16  Number    NaN
# 122              Rail            17           Week 17  Number    NaN
# 123              Rail            18           Week 18  Number    NaN
# 124              Rail            19           Week 19  Number    NaN
# 125              Rail            20           Week 20  Number    NaN
# 126              Rail            21           Week 21  Number    NaN
# 127              Rail            22           Week 22  Number    NaN
# 128              Rail            23           Week 23  Number    NaN
# 129              Rail            24           Week 24  Number    NaN
# 130              Rail            25           Week 25  Number    NaN
# 131              Rail            26           Week 26  Number    NaN
# 132              Rail            27           Week 27  Number    NaN
# 133              Rail            28           Week 28  Number    NaN
# 134              Rail            29           Week 29  Number    NaN
# 135              Rail            30           Week 30  Number    NaN
# 136              Rail            31           Week 31  Number    NaN
# 137              Rail            32           Week 32  Number    NaN
# 138              Rail            33           Week 33  Number    NaN
# 139              Rail            34           Week 34  Number    NaN
# 140              Rail            35           Week 35  Number    NaN
# 141              Rail            36           Week 36  Number    NaN
# 142              Rail            37           Week 37  Number    NaN
# 143              Rail            38           Week 38  Number    NaN
# 144              Rail            39           Week 39  Number    NaN
# 145              Rail            40           Week 40  Number    NaN
# 146              Rail            41           Week 41  Number    NaN
# 147              Rail            42           Week 42  Number    NaN
# 148              Rail            43           Week 43  Number    NaN
# 149              Rail            44           Week 44  Number    NaN
# 150              Rail            45           Week 45  Number    NaN
# 151              Rail            46           Week 46  Number    NaN
# 152              Rail            47           Week 47  Number    NaN
# 153              Rail            48           Week 48  Number    NaN
# 154              Rail            49           Week 49  Number    NaN
# 155              Rail            50           Week 50  Number    NaN
# 156              Rail            51           Week 51  Number    NaN
# 157              Rail            52           Week 52  Number    NaN
# 158              Rail            53           Week 53  Number    NaN

# %%
London2019.head()
# Out:
#     Period beginning  Bus journeys (m)  Underground journeys (m)  \
# 114               19             171.3                     106.7
# 115               19             171.3                     110.8
# 116               19             182.7                     114.1
# 117               19             156.6                     101.2
# 118               19             175.2                     106.1
#
#      DLR Journeys (m)  Tram Journeys (m)
# 114               9.3                2.2
# 115               9.7                2.2
# 116              10.0                2.2
# 117               8.9                2.0
# 118               9.7                2.2

# %%
Dublin2019.head()
# Out:
#     STATISTIC Statistic Label  TLIST(A1)  Year C01885V02316     Month    UNIT  \
# 143  TOA11C03  All Luas lines       2019  2019           01   January  Number
# 144  TOA11C03  All Luas lines       2019  2019           02  February  Number
# 145  TOA11C03  All Luas lines       2019  2019           03     March  Number
# 146  TOA11C03  All Luas lines       2019  2019           04     April  Number
# 147  TOA11C03  All Luas lines       2019  2019           05       May  Number
#
#        VALUE
# 143  3658484
# 144  3727609
# 145  4069124
# 146  3826763
# 147  4003472

# %%
#All transport 2019 - 2022 3x countries mean, var, std dev compared against population excluding rail missing data.
Dublin
# Out:
#      STATISTIC     Statistic Label TLIST(W1)          Week  C03935V04687  \
# 0     THA25C01  Passenger Journeys   2019W01  2019 Week 01            10
# 1     THA25C01  Passenger Journeys   2019W01  2019 Week 01            20
# 2     THA25C01  Passenger Journeys   2019W01  2019 Week 01            30
# 3     THA25C01  Passenger Journeys   2019W01  2019 Week 01            40
# 4     THA25C01  Passenger Journeys   2019W02  2019 Week 02            10
# ...        ...                 ...       ...           ...           ...
# 1035  THA25C01  Passenger Journeys   2023W47  2023 Week 47            40
# 1036  THA25C01  Passenger Journeys   2023W48  2023 Week 48            10
# 1037  THA25C01  Passenger Journeys   2023W48  2023 Week 48            20
# 1038  THA25C01  Passenger Journeys   2023W48  2023 Week 48            30
# 1039  THA25C01  Passenger Journeys   2023W48  2023 Week 48            40
#
#                          Mode of Transport    UNIT      VALUE
# 0                         Dublin Metro Bus  Number  1987891.0
# 1              Bus, excluding Dublin Metro  Number   497598.0
# 2                                     Rail  Number        NaN
# 3     All public transport, excluding LUAS  Number  2485489.0
# 4                         Dublin Metro Bus  Number  2709579.0
# ...                                    ...     ...        ...
# 1035  All public transport, excluding LUAS  Number  5059620.0
# 1036                      Dublin Metro Bus  Number  3453532.0
# 1037           Bus, excluding Dublin Metro  Number   941393.0
# 1038                                  Rail  Number   942218.0
# 1039  All public transport, excluding LUAS  Number  5337143.0
#
# [1040 rows x 8 columns]

# %%
Dublin = Dublin[Dublin["Mode of Transport"].str.contains("All public transport") == True]
Dublin = Dublin.dropna()
Dublin19 = Dublin[Dublin["Week"].str.contains("2019") == True]
Dublin20 = Dublin[Dublin["Week"].str.contains("2020") == True]
Dublin21 = Dublin[Dublin["Week"].str.contains("2021") == True]
Dublin22 = Dublin[Dublin["Week"].str.contains("2022") == True]

# %%
Dublin19.head()
# Out:
#    STATISTIC     Statistic Label TLIST(W1)          Week  C03935V04687  \
# 3   THA25C01  Passenger Journeys   2019W01  2019 Week 01            40
# 7   THA25C01  Passenger Journeys   2019W02  2019 Week 02            40
# 11  THA25C01  Passenger Journeys   2019W03  2019 Week 03            40
# 15  THA25C01  Passenger Journeys   2019W04  2019 Week 04            40
# 19  THA25C01  Passenger Journeys   2019W05  2019 Week 05            40
#
#                        Mode of Transport    UNIT      VALUE
# 3   All public transport, excluding LUAS  Number  2485489.0
# 7   All public transport, excluding LUAS  Number  3343343.0
# 11  All public transport, excluding LUAS  Number  3462775.0
# 15  All public transport, excluding LUAS  Number  3534486.0
# 19  All public transport, excluding LUAS  Number  3597261.0

# %%
#2019-2022 transport data mean varience and std dev Australi, Dublin, London
LTotalTransport2019 = London2019[['Bus journeys (m)', 'Underground journeys (m)', 'Tram Journeys (m)']].sum(axis=1)
LTotalTransport2020 = London2020[['Bus journeys (m)', 'Underground journeys (m)', 'Tram Journeys (m)']].sum(axis=1)
LTotalTransport2021 = London2021[['Bus journeys (m)', 'Underground journeys (m)', 'Tram Journeys (m)']].sum(axis=1)
LTotalTransport2022 = London2022[['Bus journeys (m)', 'Underground journeys (m)', 'Tram Journeys (m)']].sum(axis=1)

ATotalTransport2019 = (Australia2019[['Metropolitan tram', 'Metropolitan bus', 'Regional coach', 'Regional bus']].sum(axis=1)).div(1000000)
ATotalTransport2020 = (Australia2020[['Metropolitan tram', 'Metropolitan bus', 'Regional coach', 'Regional bus']].sum(axis=1)).div(1000000)
ATotalTransport2021 = (Australia2021[['Metropolitan tram', 'Metropolitan bus', 'Regional coach', 'Regional bus']].sum(axis=1)).div(1000000)
ATotalTransport2022 = (Australia2022[['Metropolitan tram', 'Metropolitan bus', 'Regional coach', 'Regional bus']].sum(axis=1)).div(1000000)

DTotalTransport2019 = Dublin19['VALUE'].div(1000000)
DTotalTransport2020 = Dublin20['VALUE'].div(1000000)
DTotalTransport2021 = Dublin21['VALUE'].div(1000000)
DTotalTransport2022 = Dublin22['VALUE'].div(1000000)

# %%
DTotalTransport2019
# Out:
# 3      2.485489
# 7      3.343343
# 11     3.462775
# 15     3.534486
# 19     3.597261
# 23     3.676533
# 27     3.790304
# 31     3.604972
# 35     3.695468
# 39     3.783653
# 43     3.729482
# 47     3.407670
# 51     3.886607
# 55     3.812412
# 59     3.818948
# 63     3.360396
# 67     3.136749
# 71     3.718637
# 75     3.370829
# 79     3.652188
# 83     3.639363
# 87     3.581722
# 91     3.209364
# 95     3.514291
# 99     3.507550
# 103    3.527023
# 107    3.658417
# 111    3.667128
# 115    3.596712
# 119    3.653142
# 123    3.405876
# 127    3.164567
# 131    3.422765
# 135    3.482725
# 139    3.567603
# 143    3.743607
# 147    3.929875
# 151    4.010829
# 155    4.018232
# 159    3.915759
# 163    4.067984
# 167    4.044491
# 171    3.995255
# 175    3.364007
# 179    3.906365
# 183    3.990724
# 187    3.964812
# 191    4.045954
# 195    3.989075
# 199    4.040078
# 203    4.067125
# 207    1.996529
# Name: VALUE, dtype: float64

# %%
Dublin2019.rename(columns={'VALUE': 'Luas'})
DublinBus2019.rename(columns={'VALUE': 'Bus'})
# Out:
#    STATISTIC     Statistic Label  TLIST(A1)  Year  C03935V04687  \
# 0   THA24C01  Passenger Journeys       2019  2019            10
# 1   THA24C01  Passenger Journeys       2019  2019            10
# 2   THA24C01  Passenger Journeys       2019  2019            10
# 3   THA24C01  Passenger Journeys       2019  2019            10
# 4   THA24C01  Passenger Journeys       2019  2019            10
# 5   THA24C01  Passenger Journeys       2019  2019            10
# 6   THA24C01  Passenger Journeys       2019  2019            10
# 7   THA24C01  Passenger Journeys       2019  2019            10
# 8   THA24C01  Passenger Journeys       2019  2019            10
# 9   THA24C01  Passenger Journeys       2019  2019            10
# 10  THA24C01  Passenger Journeys       2019  2019            10
# 11  THA24C01  Passenger Journeys       2019  2019            10
# 12  THA24C01  Passenger Journeys       2019  2019            10
# 13  THA24C01  Passenger Journeys       2019  2019            10
# 14  THA24C01  Passenger Journeys       2019  2019            10
# 15  THA24C01  Passenger Journeys       2019  2019            10
# 16  THA24C01  Passenger Journeys       2019  2019            10
# 17  THA24C01  Passenger Journeys       2019  2019            10
# 18  THA24C01  Passenger Journeys       2019  2019            10
# 19  THA24C01  Passenger Journeys       2019  2019            10
# 20  THA24C01  Passenger Journeys       2019  2019            10
# 21  THA24C01  Passenger Journeys       2019  2019            10
# 22  THA24C01  Passenger Journeys       2019  2019            10
# 23  THA24C01  Passenger Journeys       2019  2019            10
# 24  THA24C01  Passenger Journeys       2019  2019            10
# 25  THA24C01  Passenger Journeys       2019  2019            10
# 26  THA24C01  Passenger Journeys       2019  2019            10
# 27  THA24C01  Passenger Journeys       2019  2019            10
# 28  THA24C01  Passenger Journeys       2019  2019            10
# 29  THA24C01  Passenger Journeys       2019  2019            10
# 30  THA24C01  Passenger Journeys       2019  2019            10
# 31  THA24C01  Passenger Journeys       2019  2019            10
# 32  THA24C01  Passenger Journeys       2019  2019            10
# 33  THA24C01  Passenger Journeys       2019  2019            10
# 34  THA24C01  Passenger Journeys       2019  2019            10
# 35  THA24C01  Passenger Journeys       2019  2019            10
# 36  THA24C01  Passenger Journeys       2019  2019            10
# 37  THA24C01  Passenger Journeys       2019  2019            10
# 38  THA24C01  Passenger Journeys       2019  2019            10
# 39  THA24C01  Passenger Journeys       2019  2019            10
# 40  THA24C01  Passenger Journeys       2019  2019            10
# 41  THA24C01  Passenger Journeys       2019  2019            10
# 42  THA24C01  Passenger Journeys       2019  2019            10
# 43  THA24C01  Passenger Journeys       2019  2019            10
# 44  THA24C01  Passenger Journeys       2019  2019            10
# 45  THA24C01  Passenger Journeys       2019  2019            10
# 46  THA24C01  Passenger Journeys       2019  2019            10
# 47  THA24C01  Passenger Journeys       2019  2019            10
# 48  THA24C01  Passenger Journeys       2019  2019            10
# 49  THA24C01  Passenger Journeys       2019  2019            10
# 50  THA24C01  Passenger Journeys       2019  2019            10
# 51  THA24C01  Passenger Journeys       2019  2019            10
#
#    Mode of Transport  C01198V01436 Weeks of the year    UNIT        Bus
# 0   Dublin Metro Bus             1           Week 01  Number  1987891.0
# 1   Dublin Metro Bus             2           Week 02  Number  2709579.0
# 2   Dublin Metro Bus             3           Week 03  Number  2784678.0
# 3   Dublin Metro Bus             4           Week 04  Number  2858346.0
# 4   Dublin Metro Bus             5           Week 05  Number  2924821.0
# 5   Dublin Metro Bus             6           Week 06  Number  2979960.0
# 6   Dublin Metro Bus             7           Week 07  Number  3053710.0
# 7   Dublin Metro Bus             8           Week 08  Number  2927041.0
# 8   Dublin Metro Bus             9           Week 09  Number  2989171.0
# 9   Dublin Metro Bus            10           Week 10  Number  3065148.0
# 10  Dublin Metro Bus            11           Week 11  Number  2998440.0
# 11  Dublin Metro Bus            12           Week 12  Number  2742468.0
# 12  Dublin Metro Bus            13           Week 13  Number  3136873.0
# 13  Dublin Metro Bus            14           Week 14  Number  3087216.0
# 14  Dublin Metro Bus            15           Week 15  Number  3101074.0
# 15  Dublin Metro Bus            16           Week 16  Number  2723661.0
# 16  Dublin Metro Bus            17           Week 17  Number  2535513.0
# 17  Dublin Metro Bus            18           Week 18  Number  2990676.0
# 18  Dublin Metro Bus            19           Week 19  Number  2719955.0
# 19  Dublin Metro Bus            20           Week 20  Number  2960967.0
# 20  Dublin Metro Bus            21           Week 21  Number  2938021.0
# 21  Dublin Metro Bus            22           Week 22  Number  2900323.0
# 22  Dublin Metro Bus            23           Week 23  Number  2591616.0
# 23  Dublin Metro Bus            24           Week 24  Number  2844409.0
# 24  Dublin Metro Bus            25           Week 25  Number  2826773.0
# 25  Dublin Metro Bus            26           Week 26  Number  2840156.0
# 26  Dublin Metro Bus            27           Week 27  Number  2953254.0
# 27  Dublin Metro Bus            28           Week 28  Number  2954091.0
# 28  Dublin Metro Bus            29           Week 29  Number  2895372.0
# 29  Dublin Metro Bus            30           Week 30  Number  2939485.0
# 30  Dublin Metro Bus            31           Week 31  Number  2725260.0
# 31  Dublin Metro Bus            32           Week 32  Number  2547806.0
# 32  Dublin Metro Bus            33           Week 33  Number  2724875.0
# 33  Dublin Metro Bus            34           Week 34  Number  2793023.0
# 34  Dublin Metro Bus            35           Week 35  Number  2872215.0
# 35  Dublin Metro Bus            36           Week 36  Number  2999569.0
# 36  Dublin Metro Bus            37           Week 37  Number  3109763.0
# 37  Dublin Metro Bus            38           Week 38  Number  3182473.0
# 38  Dublin Metro Bus            39           Week 39  Number  3204042.0
# 39  Dublin Metro Bus            40           Week 40  Number  3139165.0
# 40  Dublin Metro Bus            41           Week 41  Number  3243670.0
# 41  Dublin Metro Bus            42           Week 42  Number  3238993.0
# 42  Dublin Metro Bus            43           Week 43  Number  3170924.0
# 43  Dublin Metro Bus            44           Week 44  Number  2708101.0
# 44  Dublin Metro Bus            45           Week 45  Number  3130443.0
# 45  Dublin Metro Bus            46           Week 46  Number  3206894.0
# 46  Dublin Metro Bus            47           Week 47  Number  3192052.0
# 47  Dublin Metro Bus            48           Week 48  Number  3251721.0
# 48  Dublin Metro Bus            49           Week 49  Number  3215990.0
# 49  Dublin Metro Bus            50           Week 50  Number  3271738.0
# 50  Dublin Metro Bus            51           Week 51  Number  3166707.0
# 51  Dublin Metro Bus            52           Week 52  Number  1599369.0

# %%
Dublin2019.head()
# Out:
#     STATISTIC Statistic Label  TLIST(A1)  Year C01885V02316     Month    UNIT  \
# 143  TOA11C03  All Luas lines       2019  2019           01   January  Number
# 144  TOA11C03  All Luas lines       2019  2019           02  February  Number
# 145  TOA11C03  All Luas lines       2019  2019           03     March  Number
# 146  TOA11C03  All Luas lines       2019  2019           04     April  Number
# 147  TOA11C03  All Luas lines       2019  2019           05       May  Number
#
#        VALUE
# 143  3658484
# 144  3727609
# 145  4069124
# 146  3826763
# 147  4003472

# %%
ATotalTransport2019.describe()
# Out:
# count    12.000000
# mean     28.063000
# std       2.762459
# min      23.579359
# 25%      26.671798
# 50%      28.018321
# 75%      29.767298
# max      32.577595
# dtype: float64

# %%
Table = {
    'Country_City': ['Australia', 'Australia', 'Australia', 'Australia', 'Dublin', 'Dublin', 'Dublin', 'Dublin', 'London', 'London',  'London', 'London',],
    'Year': [2019, 2020, 2021, 2022, 2019, 2020, 2021, 2022, 2019, 2020, 2021, 2022],
    'Mean':[ATotalTransport2019.mean(),ATotalTransport2020.mean(),ATotalTransport2021.mean(),ATotalTransport2022.mean(),DTotalTransport2019.mean(),DTotalTransport2020.mean(),DTotalTransport2021.mean(),DTotalTransport2022.mean(),LTotalTransport2019.mean(),LTotalTransport2020.mean(),LTotalTransport2021.mean(),LTotalTransport2022.mean()],
    'std':[ATotalTransport2019.std(),ATotalTransport2020.std(),ATotalTransport2021.std(),ATotalTransport2022.std(),DTotalTransport2019.std(),DTotalTransport2020.std(),DTotalTransport2021.std(),DTotalTransport2022.std(),LTotalTransport2019.std(),LTotalTransport2020.std(),LTotalTransport2021.std(),LTotalTransport2022.std()],
    'Var':[ATotalTransport2019.var(),ATotalTransport2020.var(),ATotalTransport2021.var(),ATotalTransport2022.var(),DTotalTransport2019.var(),DTotalTransport2020.var(),DTotalTransport2021.var(),DTotalTransport2022.var(),LTotalTransport2019.var(),LTotalTransport2020.var(),LTotalTransport2021.var(),LTotalTransport2022.var()]
}
df = pd.DataFrame(Table)

df.head(12)
# Out:
#    Country_City  Year        Mean        std          Var
# 0     Australia  2019   28.063000   2.762459     7.631178
# 1     Australia  2020   10.819468   7.814730    61.070001
# 2     Australia  2021   11.837484   4.260931    18.155535
# 3     Australia  2022   18.747756   3.357038    11.269705
# 4        Dublin  2019    3.626099   0.378985     0.143629
# 5        Dublin  2020    2.194452   1.349001     1.819805
# 6        Dublin  2021    2.240090   0.793868     0.630227
# 7        Dublin  2022    3.898686   0.645349     0.416475
# 8        London  2019  277.176923  19.139974   366.338590
# 9        London  2020  128.453846  77.902520  6068.802692
# 10       London  2021  147.884615  45.094121  2033.479744
# 11       London  2022  212.246154  18.725945   350.661026

# %%
from prettytable import PrettyTable

descriptivestats = PrettyTable()

descriptivestats.field_names = ["Country_City", "Year", "Mean", "std", "Var"]
descriptivestats.add_row(["Australia",2019, 28.063000, 2.762459, 7.631178])
descriptivestats.add_row(["Australia",2020,10.819468,7.814730,61.070001])
descriptivestats.add_row(["Australia",2021,11.837484,4.260931,18.155535])
descriptivestats.add_row(["Australia",2022,18.747756,3.357038,11.269705])
descriptivestats.add_row(["Dublin", 2019,3.626099,0.378985,0.143629])
descriptivestats.add_row(["Dublin", 2020,2.194452,1.349001,1.819805])
descriptivestats.add_row(["Dublin", 2021,2.240090,0.793868,0.630227])
descriptivestats.add_row(["Dublin", 2022,3.898686,0.645349,0.416475])
descriptivestats.add_row(["London", 2019,277.176923,19.139974,366.338590])
descriptivestats.add_row(["London", 2020,128.453846,77.902520,6068.802692])
descriptivestats.add_row(["London", 2021,147.884615,45.094121,2033.479744])
descriptivestats.add_row(["London", 2022,212.246154,18.725945,350.661026])

print(descriptivestats)
# Out:
# +--------------+------+------------+-----------+-------------+
# | Country_City | Year |    Mean    |    std    |     Var     |
# +--------------+------+------------+-----------+-------------+
# |  Australia   | 2019 |   28.063   |  2.762459 |   7.631178  |
# |  Australia   | 2020 | 10.819468  |  7.81473  |  61.070001  |
# |  Australia   | 2021 | 11.837484  |  4.260931 |  18.155535  |
# |  Australia   | 2022 | 18.747756  |  3.357038 |  11.269705  |
# |    Dublin    | 2019 |  3.626099  |  0.378985 |   0.143629  |
# |    Dublin    | 2020 |  2.194452  |  1.349001 |   1.819805  |
# |    Dublin    | 2021 |  2.24009   |  0.793868 |   0.630227  |
# |    Dublin    | 2022 |  3.898686  |  0.645349 |   0.416475  |
# |    London    | 2019 | 277.176923 | 19.139974 |  366.33859  |
# |    London    | 2020 | 128.453846 |  77.90252 | 6068.802692 |
# |    London    | 2021 | 147.884615 | 45.094121 | 2033.479744 |
# |    London    | 2022 | 212.246154 | 18.725945 |  350.661026 |
# +--------------+------+------------+-----------+-------------+

# %%
#Machine Learning

# %%
#make a dataset that has Australia, london and dublin yearly data
Australiacolumnsums2020 = Dublin2019.sum(axis=0)
Australiacolumnsums2020
# Out:
# STATISTIC          TOA11C03TOA11C03TOA11C03TOA11C03TOA11C03TOA11C...
# Statistic Label    All Luas linesAll Luas linesAll Luas linesAll ...
# TLIST(A1)                                                      24228
# Year                                                           24228
# C01885V02316                                010203040506070809101112
# Month              JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...
# UNIT               NumberNumberNumberNumberNumberNumberNumberNumb...
# VALUE                                                       48347231
# dtype: object

# %%
#EDA
Dublin.shape
# Out:
# (257, 8)

# %%
Dublin10.columns.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[378], line 1
# ----> 1 Dublin10.columns.values
#
# NameError: name 'Dublin10' is not defined

# %%
Dublin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 257 entries, 3 to 1039
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   STATISTIC          257 non-null    object
#  1   Statistic Label    257 non-null    object
#  2   TLIST(W1)          257 non-null    object
#  3   Week               257 non-null    object
#  4   C03935V04687       257 non-null    int64
#  5   Mode of Transport  257 non-null    object
#  6   UNIT               257 non-null    object
#  7   VALUE              257 non-null    float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 18.1+ KB

# %%
#Fixing column names
Dublin.rename(columns= {"Statistic Label": "StatisticLabel",
                       "Mode of Transport": "ModeofTransport"})
# Out:
#      STATISTIC      StatisticLabel TLIST(W1)          Week  C03935V04687  \
# 3     THA25C01  Passenger Journeys   2019W01  2019 Week 01            40
# 7     THA25C01  Passenger Journeys   2019W02  2019 Week 02            40
# 11    THA25C01  Passenger Journeys   2019W03  2019 Week 03            40
# 15    THA25C01  Passenger Journeys   2019W04  2019 Week 04            40
# 19    THA25C01  Passenger Journeys   2019W05  2019 Week 05            40
# ...        ...                 ...       ...           ...           ...
# 1023  THA25C01  Passenger Journeys   2023W44  2023 Week 44            40
# 1027  THA25C01  Passenger Journeys   2023W45  2023 Week 45            40
# 1031  THA25C01  Passenger Journeys   2023W46  2023 Week 46            40
# 1035  THA25C01  Passenger Journeys   2023W47  2023 Week 47            40
# 1039  THA25C01  Passenger Journeys   2023W48  2023 Week 48            40
#
#                            ModeofTransport    UNIT      VALUE
# 3     All public transport, excluding LUAS  Number  2485489.0
# 7     All public transport, excluding LUAS  Number  3343343.0
# 11    All public transport, excluding LUAS  Number  3462775.0
# 15    All public transport, excluding LUAS  Number  3534486.0
# 19    All public transport, excluding LUAS  Number  3597261.0
# ...                                    ...     ...        ...
# 1023  All public transport, excluding LUAS  Number  4680193.0
# 1027  All public transport, excluding LUAS  Number  5406041.0
# 1031  All public transport, excluding LUAS  Number  5113447.0
# 1035  All public transport, excluding LUAS  Number  5059620.0
# 1039  All public transport, excluding LUAS  Number  5337143.0
#
# [257 rows x 8 columns]

# %%
CombinedData = {'Country': ['Australia', 'Australia','Australia', 'Australia', 'London', 'London','London', 'London', 'Dublin', 'Dublin','Dublin', 'Dublin'],
        'Year': [19,20,21,22,19,20,21,22,19,20,21,22],
        'BusJourneysMillions': [138.42, 65.13,71.22,125.20,2180.50,1144.80,1294.00,1737.70,151.66,78.02,78.37,132.60],
               'TramJourneysMillions': [198.56,63.32,70.81,99.76,27.60,15.10,17.00,20.30,48.34,19.17,19.48,38.67]}

CombinedDataFrame = pd.DataFrame(CombinedData)

# %%
CombinedDataFrame.nunique(axis=0)
# Out:
# Country                  3
# Year                     4
# BusJourneysMillions     12
# TramJourneysMillions    12
# dtype: int64

# %%
CombinedDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               12 non-null     object
#  1   Year                  12 non-null     int64
#  2   BusJourneysMillions   12 non-null     float64
#  3   TramJourneysMillions  12 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 512.0+ bytes

# %%
#correlation = df.corr()
#print(correlation)

#df_heatmap = df.pivot("Country", "Year", "BusJourneysMillions", "TramJourneysMillions" )
#sns.heatmap(df_heatmap)

# %%
DublinBus = DublinBus.dropna()

# %%
DublinBus.isnull().sum()
# Out:
# STATISTIC            0
# Statistic Label      0
# TLIST(A1)            0
# Year                 0
# C03935V04687         0
# Mode of Transport    0
# C01198V01436         0
# Weeks of the year    0
# UNIT                 0
# VALUE                0
# dtype: int64

# %%
DublinBus
# Out:
#      STATISTIC     Statistic Label  TLIST(A1)  Year  C03935V04687  \
# 0     THA24C01  Passenger Journeys       2019  2019            10
# 1     THA24C01  Passenger Journeys       2019  2019            10
# 2     THA24C01  Passenger Journeys       2019  2019            10
# 3     THA24C01  Passenger Journeys       2019  2019            10
# 4     THA24C01  Passenger Journeys       2019  2019            10
# ...        ...                 ...        ...   ...           ...
# 1045  THA24C01  Passenger Journeys       2023  2023            40
# 1046  THA24C01  Passenger Journeys       2023  2023            40
# 1047  THA24C01  Passenger Journeys       2023  2023            40
# 1048  THA24C01  Passenger Journeys       2023  2023            40
# 1049  THA24C01  Passenger Journeys       2023  2023            40
#
#                          Mode of Transport  C01198V01436 Weeks of the year  \
# 0                         Dublin Metro Bus             1           Week 01
# 1                         Dublin Metro Bus             2           Week 02
# 2                         Dublin Metro Bus             3           Week 03
# 3                         Dublin Metro Bus             4           Week 04
# 4                         Dublin Metro Bus             5           Week 05
# ...                                    ...           ...               ...
# 1045  All public transport, excluding LUAS            39           Week 39
# 1046  All public transport, excluding LUAS            40           Week 40
# 1047  All public transport, excluding LUAS            41           Week 41
# 1048  All public transport, excluding LUAS            42           Week 42
# 1049  All public transport, excluding LUAS            43           Week 43
#
#         UNIT      VALUE
# 0     Number  1987891.0
# 1     Number  2709579.0
# 2     Number  2784678.0
# 3     Number  2858346.0
# 4     Number  2924821.0
# ...      ...        ...
# 1045  Number  5400563.0
# 1046  Number  5464525.0
# 1047  Number  5478003.0
# 1048  Number  5338868.0
# 1049  Number  5366554.0
#
# [956 rows x 10 columns]

# %%
DublinBus = DublinBus.drop(columns=['STATISTIC', 'Statistic Label', 'TLIST(A1)', 'C03935V04687', 'C01198V01436', 'UNIT'], axis = 1)

# %%
DublinBus.rename(columns= {"Weeks of the year": "WeeksOfTheYear",
                       "Mode of Transport": "ModeofTransport"})
# Out:
#       Year                       ModeofTransport WeeksOfTheYear      VALUE
# 0     2019                      Dublin Metro Bus        Week 01  1987891.0
# 1     2019                      Dublin Metro Bus        Week 02  2709579.0
# 2     2019                      Dublin Metro Bus        Week 03  2784678.0
# 3     2019                      Dublin Metro Bus        Week 04  2858346.0
# 4     2019                      Dublin Metro Bus        Week 05  2924821.0
# ...    ...                                   ...            ...        ...
# 1045  2023  All public transport, excluding LUAS        Week 39  5400563.0
# 1046  2023  All public transport, excluding LUAS        Week 40  5464525.0
# 1047  2023  All public transport, excluding LUAS        Week 41  5478003.0
# 1048  2023  All public transport, excluding LUAS        Week 42  5338868.0
# 1049  2023  All public transport, excluding LUAS        Week 43  5366554.0
#
# [956 rows x 4 columns]

# %%
DublinBus.columns.values
# Out:
# array(['Year', 'Mode of Transport', 'Weeks of the year', 'VALUE'],
#       dtype=object)

# %%
DublinBus = DublinBus[DublinBus["Year"] != 2023]
DublinBus
# Out:
#      Year                     Mode of Transport Weeks of the year      VALUE
# 0    2019                      Dublin Metro Bus           Week 01  1987891.0
# 1    2019                      Dublin Metro Bus           Week 02  2709579.0
# 2    2019                      Dublin Metro Bus           Week 03  2784678.0
# 3    2019                      Dublin Metro Bus           Week 04  2858346.0
# 4    2019                      Dublin Metro Bus           Week 05  2924821.0
# ..    ...                                   ...               ...        ...
# 842  2022  All public transport, excluding LUAS           Week 48  4810091.0
# 843  2022  All public transport, excluding LUAS           Week 49  4746525.0
# 844  2022  All public transport, excluding LUAS           Week 50  4656099.0
# 845  2022  All public transport, excluding LUAS           Week 51  4023247.0
# 846  2022  All public transport, excluding LUAS           Week 52  3730211.0
#
# [784 rows x 4 columns]

# %%
scaler = StandardScaler()

df_scale = pd.DataFrame(scaler.fit_transform(DublinBus),columns=DublinBus.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10372\1944597334.py in ?()
#       1 scaler = StandardScaler()
#       2
# ----> 3 df_scale = pd.DataFrame(scaler.fit_transform(DublinBus),columns=DublinBus.columns)
#
# ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#     160             return_tuple = (
#
# ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     912         # non-optimized default implementation; override when a better
#     913         # method is possible for a given clustering algorithm
#     914         if y is None:
#     915             # fit method of arity 1 (unsupervised transformation)
# --> 916             return self.fit(X, **fit_params).transform(X)
#     917         else:
#     918             # fit method of arity 2 (supervised transformation)
#     919             return self.fit(X, y, **fit_params).transform(X)
#
# ~\anaconda3\envs\notebook\lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     835             Fitted scaler.
#     836         """
#     837         # Reset internal state before fitting
#     838         self._reset()
# --> 839         return self.partial_fit(X, y, sample_weight)
#
# ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1148                 skip_parameter_validation=(
#    1149                     prefer_skip_nested_validation or global_skip_validation
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\envs\notebook\lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     871         self : object
#     872             Fitted scaler.
#     873         """
#     874         first_call = not hasattr(self, "n_samples_seen_")
# --> 875         X = self._validate_data(
#     876             X,
#     877             accept_sparse=("csr", "csc"),
#     878             dtype=FLOAT_DTYPES,
#
# ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     601                 out = y
#     602             else:
#     603                 out = X, y
#     604         elif not no_val_X and no_val_y:
# --> 605             out = check_array(X, input_name="X", **check_params)
#     606         elif no_val_X and not no_val_y:
#     607             out = _check_y(y, **check_params)
#     608         else:
#
# ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     912                         )
#     913                     array = xp.astype(array, dtype, copy=False)
#     914                 else:
#     915                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 916             except ComplexWarning as complex_warning:
#     917                 raise ValueError(
#     918                     "Complex data not supported\n{}\n".format(array)
#     919                 ) from complex_warning
#
# ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     376         # Use NumPy API to support order
#     377         if copy is True:
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#     383         # container that is consistent with the input's namespace.
#
# ~\anaconda3\envs\notebook\lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2082     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083         values = self._values
# -> 2084         arr = np.asarray(values, dtype=dtype)
#    2085         if (
#    2086             astype_is_view(values.dtype, arr.dtype)
#    2087             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Dublin Metro Bus'

# %%
#seperating dataset into test and train. supervised machine learning
y = DublinBus['Mode of Transport']
X = df_scale.drop(['Mode of Transport'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[393], line 3
#       1 #seperating dataset into test and train. supervised machine learning
#       2 y = DublinBus['Mode of Transport']
# ----> 3 X = df_scale.drop(['Mode of Transport'],axis=1)
#
# NameError: name 'df_scale' is not defined

# %%
#seperating dataset into test and train. supervised machine learning
y = DublinBus['Mode of Transport']
X = df_scale.drop(['Mode of Transport'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[394], line 3
#       1 #seperating dataset into test and train. supervised machine learning
#       2 y = DublinBus['Mode of Transport']
# ----> 3 X = df_scale.drop(['Mode of Transport'],axis=1)
#
# NameError: name 'df_scale' is not defined

# %%
#setting test size to 0.2 and training size to 0.8 with random state 0.95
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.20, random_state= 95)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[395], line 2
#       1 #setting test size to 0.2 and training size to 0.8 with random state 0.95
# ----> 2 X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.20, random_state= 95)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\model_selection\_split.py:2646, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2643 if n_arrays == 0:
#    2644     raise ValueError("At least one array required as input")
# -> 2646 arrays = indexable(*arrays)
#    2648 n_samples = _num_samples(arrays[0])
#    2649 n_train, n_test = _validate_shuffle_split(
#    2650     n_samples, test_size, train_size, default_test_size=0.25
#    2651 )
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\validation.py:453, in indexable(*iterables)
#     434 """Make arrays indexable for cross-validation.
#     435
#     436 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     449     sparse matrix, or dataframe) or `None`.
#     450 """
#     452 result = [_make_indexable(X) for X in iterables]
# --> 453 check_consistent_length(*result)
#     454 return result
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 784]

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)

#I couldnt get my X and Y Train data to fit so I am filling in code I would use if I could get my dataset set working wiht the model

# %%
lrm = LinearRegression()
lrm.fit(X_train, Y_train) #fit an OLS model
LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[396], line 2
#       1 lrm = LinearRegression()
# ----> 2 lrm.fit(X_train, Y_train) #fit an OLS model
#       3 LinearRegression()
#
# NameError: name 'X_train' is not defined

# %%
y_preds_train = lrm.predict(X_train)
y_preds_test = lrm.predict(X_test)  #making lrm predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[397], line 1
# ----> 1 y_preds_train = lrm.predict(X_train)
#       2 y_preds_test = lrm.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
print("The R-squared of the model in training set is: {}".format(lrm.score(X_train, Y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(lrm.score(X_test, Y_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(Y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((Y_test - y_preds_test) / Y_test)) * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[398], line 1
# ----> 1 print("The R-squared of the model in training set is: {}".format(lrm.score(X_train, Y_train)))
#       2 print("-----Test set statistics-----")
#       3 print("R-squared of the model in test set is: {}".format(lrm.score(X_test, Y_test)))
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# Usually, a RMSE score of less than 180 is considered a good score for a moderately or well working algorithm. In the caseof it exceeding 180, we need to perform feature selection and hyper parameter tuning on the parameters of the model.
# I would expect the Value to exceed 180 in this Case

# %%
# Using GridSearch for parameter optimization
ridgeregr = GridSearchCV(Ridge(),
                    param_grid={
                        'alpha': [0.01, 0.1, 1]
                    }, verbose=1)

ridgeregr.fit(X_train, Y_train)

ridge = ridgeregr.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[399], line 7
#       1 # Using GridSearch for parameter optimization
#       2 ridgeregr = GridSearchCV(Ridge(),
#       3                     param_grid={
#       4                         'alpha': [0.01, 0.1, 1]
#       5                     }, verbose=1)
# ----> 7 ridgeregr.fit(X_train, Y_train)
#       9 ridge = ridgeregr.best_estimator_
#
# NameError: name 'X_train' is not defined

# %%
# Making predictions here
y_preds_train = ridge.predict(X_train)
y_preds_test_ridge = ridge.predict(X_test)

print("R-squared of the model in training set is: {}".format(ridge.score(X_train, Y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(ridge.score(X_test, Y_test)))
print("Root mean squared error of the prediction is: {}".format(mse(Y_test, y_preds_test_ridge)**(1/2)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((Y_test - y_preds_test_ridge) / Y_test)) * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[400], line 2
#       1 # Making predictions here
# ----> 2 y_preds_train = ridge.predict(X_train)
#       3 y_preds_test_ridge = ridge.predict(X_test)
#       5 print("R-squared of the model in training set is: {}".format(ridge.score(X_train, Y_train)))
#
# NameError: name 'ridge' is not defined

# %%
CombinedTramData = pd.concat([df["Mean"], df["std"], df["Var"]])

# %%
scaler2 = StandardScaler()
n=scaler.fit_transform(CombinedTramData)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[402], line 2
#       1 scaler2 = StandardScaler()
# ----> 2 n=scaler.fit_transform(CombinedTramData)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py:916, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     912 # non-optimized default implementation; override when a better
#     913 # method is possible for a given clustering algorithm
#     914 if y is None:
#     915     # fit method of arity 1 (unsupervised transformation)
# --> 916     return self.fit(X, **fit_params).transform(X)
#     917 else:
#     918     # fit method of arity 2 (supervised transformation)
#     919     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\preprocessing\_data.py:839, in StandardScaler.fit(self, X, y, sample_weight)
#     837 # Reset internal state before fitting
#     838 self._reset()
# --> 839 return self.partial_fit(X, y, sample_weight)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\preprocessing\_data.py:875, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     843 """Online computation of mean and std on X for later scaling.
#     844
#     845 All of X is processed as a single batch. This is intended for cases
#    (...)
#     872     Fitted scaler.
#     873 """
#     874 first_call = not hasattr(self, "n_samples_seen_")
# --> 875 X = self._validate_data(
#     876     X,
#     877     accept_sparse=("csr", "csc"),
#     878     dtype=FLOAT_DTYPES,
#     879     force_all_finite="allow-nan",
#     880     reset=first_call,
#     881 )
#     882 n_features = X.shape[1]
#     884 if sample_weight is not None:
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py:605, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     603         out = X, y
#     604 elif not no_val_X and no_val_y:
# --> 605     out = check_array(X, input_name="X", **check_params)
#     606 elif no_val_X and not no_val_y:
#     607     out = _check_y(y, **check_params)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\validation.py:938, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     936     # If input is 1D raise error
#     937     if array.ndim == 1:
# --> 938         raise ValueError(
#     939             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     940             "Reshape your data either using array.reshape(-1, 1) if "
#     941             "your data has a single feature or array.reshape(1, -1) "
#     942             "if it contains a single sample.".format(array)
#     943         )
#     945 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#     946     raise ValueError(
#     947         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     948         "Convert your data to numeric values explicitly instead."
#     949     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[2.80629997e+01 1.08194685e+01 1.18374840e+01 1.87477559e+01
#  3.62609906e+00 2.19445208e+00 2.24009029e+00 3.89868579e+00
#  2.77176923e+02 1.28453846e+02 1.47884615e+02 2.12246154e+02
#  2.76245873e+00 7.81472971e+00 4.26093119e+00 3.35703819e+00
#  3.78984745e-01 1.34900132e+00 7.93868261e-01 6.45349026e-01
#  1.91399736e+01 7.79025204e+01 4.50941209e+01 1.87259453e+01
#  7.63117823e+00 6.10700005e+01 1.81555346e+01 1.12697054e+01
#  1.43629437e-01 1.81980457e+00 6.30226815e-01 4.16475365e-01
#  3.66338590e+02 6.06880269e+03 2.03347974e+03 3.50661026e+02].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
from sklearn.cluster import KMeans

#Assuming value of 6 for x to let code run
x=6

kmeans = KMeans(n_clusters = 3, max_iter = 400, n_init = 10, random_state = 0)

y_kmeans = kmeans.fit_predict(x)

print(y_kmeans)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[403], line 8
#       4 x=6
#       6 kmeans = KMeans(n_clusters = 3, max_iter = 400, n_init = 10, random_state = 0)
# ----> 8 y_kmeans = kmeans.fit_predict(x)
#      10 print(y_kmeans)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\cluster\_kmeans.py:1069, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1046 def fit_predict(self, X, y=None, sample_weight=None):
#    1047     """Compute cluster centers and predict cluster index for each sample.
#    1048
#    1049     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#    1067         Index of the cluster each sample belongs to.
#    1068     """
# -> 1069     return self.fit(X, sample_weight=sample_weight).labels_
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\cluster\_kmeans.py:1475, in KMeans.fit(self, X, y, sample_weight)
#    1447 @_fit_context(prefer_skip_nested_validation=True)
#    1448 def fit(self, X, y=None, sample_weight=None):
#    1449     """Compute k-means clustering.
#    1450
#    1451     Parameters
#    (...)
#    1473         Fitted estimator.
#    1474     """
# -> 1475     X = self._validate_data(
#    1476         X,
#    1477         accept_sparse="csr",
#    1478         dtype=[np.float64, np.float32],
#    1479         order="C",
#    1480         copy=self.copy_x,
#    1481         accept_large_sparse=False,
#    1482     )
#    1484     self._check_params_vs_input(X)
#    1486     random_state = check_random_state(self.random_state)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py:605, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     603         out = X, y
#     604 elif not no_val_X and no_val_y:
# --> 605     out = check_array(X, input_name="X", **check_params)
#     606 elif no_val_X and not no_val_y:
#     607     out = _check_y(y, **check_params)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\validation.py:930, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     927 if ensure_2d:
#     928     # If input is scalar raise error
#     929     if array.ndim == 0:
# --> 930         raise ValueError(
#     931             "Expected 2D array, got scalar array instead:\narray={}.\n"
#     932             "Reshape your data either using array.reshape(-1, 1) if "
#     933             "your data has a single feature or array.reshape(1, -1) "
#     934             "if it contains a single sample.".format(array)
#     935         )
#     936     # If input is 1D raise error
#     937     if array.ndim == 1:
#
# ValueError: Expected 2D array, got scalar array instead:
# array=6.0.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 30)
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 30)
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 30)


# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1:2], s = 100, c = 'blue', label = 'Centroids')
plt.xlabel('Years')
plt.ylabel('Transport in millions')

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[404], line 1
# ----> 1 plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 30)
#       2 plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 30)
#       3 plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 30)
#
# NameError: name 'y_kmeans' is not defined

# %%
#Finding the optimum number of clusters for k-means classification
from sklearn.cluster import KMeans
array = []                  # Declare an array

# Set the loop from the minimum and maximum values
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    array.append(kmeans.inertia_)
# inertia_float: Sum of squared distances of samples to their closest cluster center.

# Plotting the results onto a line graph, allowing us to observe 'The elbow'
plt.plot(range(1, 11), array)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('array')    # within cluster sum of squares
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[405], line 8
#       6 for i in range(1, 11):
#       7     kmeans = KMeans(n_clusters = i, max_iter = 300, n_init = 10, random_state = 0)
# ----> 8     kmeans.fit(x)
#       9     array.append(kmeans.inertia_)
#      10 # inertia_float: Sum of squared distances of samples to their closest cluster center.
#      11
#      12 # Plotting the results onto a line graph, allowing us to observe 'The elbow'
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\cluster\_kmeans.py:1475, in KMeans.fit(self, X, y, sample_weight)
#    1447 @_fit_context(prefer_skip_nested_validation=True)
#    1448 def fit(self, X, y=None, sample_weight=None):
#    1449     """Compute k-means clustering.
#    1450
#    1451     Parameters
#    (...)
#    1473         Fitted estimator.
#    1474     """
# -> 1475     X = self._validate_data(
#    1476         X,
#    1477         accept_sparse="csr",
#    1478         dtype=[np.float64, np.float32],
#    1479         order="C",
#    1480         copy=self.copy_x,
#    1481         accept_large_sparse=False,
#    1482     )
#    1484     self._check_params_vs_input(X)
#    1486     random_state = check_random_state(self.random_state)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\base.py:605, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     603         out = X, y
#     604 elif not no_val_X and no_val_y:
# --> 605     out = check_array(X, input_name="X", **check_params)
#     606 elif no_val_X and not no_val_y:
#     607     out = _check_y(y, **check_params)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\validation.py:930, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     927 if ensure_2d:
#     928     # If input is scalar raise error
#     929     if array.ndim == 0:
# --> 930         raise ValueError(
#     931             "Expected 2D array, got scalar array instead:\narray={}.\n"
#     932             "Reshape your data either using array.reshape(-1, 1) if "
#     933             "your data has a single feature or array.reshape(1, -1) "
#     934             "if it contains a single sample.".format(array)
#     935         )
#     936     # If input is 1D raise error
#     937     if array.ndim == 1:
#
# ValueError: Expected 2D array, got scalar array instead:
# array=6.0.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
# split Train and Test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[406], line 3
#       1 # split Train and Test
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\model_selection\_split.py:2646, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2643 if n_arrays == 0:
#    2644     raise ValueError("At least one array required as input")
# -> 2646 arrays = indexable(*arrays)
#    2648 n_samples = _num_samples(arrays[0])
#    2649 n_train, n_test = _validate_shuffle_split(
#    2650     n_samples, test_size, train_size, default_test_size=0.25
#    2651 )
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\validation.py:453, in indexable(*iterables)
#     434 """Make arrays indexable for cross-validation.
#     435
#     436 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     449     sparse matrix, or dataframe) or `None`.
#     450 """
#     452 result = [_make_indexable(X) for X in iterables]
# --> 453 check_consistent_length(*result)
#     454 return result
#
# File ~\anaconda3\envs\notebook\lib\site-packages\sklearn\utils\validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 784]

# %%
from sklearn.svm import SVC
svc_model = SVC()
svc_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[407], line 3
#       1 from sklearn.svm import SVC
#       2 svc_model = SVC()
# ----> 3 svc_model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.metrics import classification_report, confusion_matrix


y_predict = svc_model.predict(X_test)
cm = confusion_matrix(y_test, y_predict)
sns.heatmap(cm, annot=True)
print(classification_report(y_test, y_predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[408], line 4
#       1 from sklearn.metrics import classification_report, confusion_matrix
# ----> 4 y_predict = svc_model.predict(X_test)
#       5 cm = confusion_matrix(y_test, y_predict)
#       6 sns.heatmap(cm, annot=True)
#
# NameError: name 'X_test' is not defined

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\leega\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#sentiment analysis, reviews from trust pilot related to dublin bus
from nltk.tokenize import sent_tokenize
text="""I was trying to go to the square from kimmage. I was waiting for the bus in the freezing cold and kept waiting and waiting and then it got cancelled,I had to wait for the next bus that was in an hour. Again I waited but it kept getting delayed at the end it got delayed 30 minutes and then it got cancelled again! And so I wasted 1 hour and 30 minutes for the bus that didn’t even come? I’m disappointed. I’ve been getting the bus to work for almost 20 years, and it was never great, but it has gotten steadily worse over the past few years but especially the last year. Buses constantly disappear, or come extremely late - I have waited an extra 20–30mins for buses 4/5 evenings after work consistently since September.
The buses in the morning come relatively on time, but then sometimes stop for up to 10 mins “to get back on schedule” when they certainly weren’t 10 minutes early. Was passed by a bus due 5 minutes after mine while we sat waiting, which makes no sense.
There also seems to be endless buses for certain areas, Adamstown for example has such an abundance of buses, on December 13th seven C1’s, and one C2 passed by my stop within 10 minutes. All of them almost empty. This is unacceptable when there are others that simply don’t show or as mentioned, are often half an hour late.
We have the worst public transport for a major city in Europe, and it’s not cheap, something needs to be fixed. I had gone mad all night looking for my wallet, lost all hope and decided to go home. When I got on the 42n Wayne, the bus driver, recognised me as I got on. He asked me if I had lost my wallet, called the inspector after he got a better look to confirm it was me. All in the span of 5-10 minutes the inspector came with my wallet, thank you Wayne and the inspector absolutely saved me an absolutely massive headache. Good people in Dublin bus. 0/5 or if possible I ll rate in minus. It's hell, unpredictable, uncomfortable and cost a lot of nerves. For common people with work schedule or study or other important business every minute can count but the buses are so unpredictable - sometimes they delayed, sometimes they even dont come, the system is terrible. Especially during cold the waiting turns to torture"""
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['I was trying to go to the square from kimmage.', 'I was waiting for the bus in the freezing cold and kept waiting and waiting and then it got cancelled,I had to wait for the next bus that was in an hour.', 'Again I waited but it kept getting delayed at the end it got delayed 30 minutes and then it got cancelled again!', 'And so I wasted 1 hour and 30 minutes for the bus that didn’t even come?', 'I’m disappointed.', 'I’ve been getting the bus to work for almost 20 years, and it was never great, but it has gotten steadily worse over the past few years but especially the last year.', 'Buses constantly disappear, or come extremely late - I have waited an extra 20–30mins for buses 4/5 evenings after work consistently since September.', 'The buses in the morning come relatively on time, but then sometimes stop for up to 10 mins “to get back on schedule” when they certainly weren’t 10 minutes early.', 'Was passed by a bus due 5 minutes after mine while we sat waiting, which makes no sense.', 'There also seems to be endless buses for certain areas, Adamstown for example has such an abundance of buses, on December 13th seven C1’s, and one C2 passed by my stop within 10 minutes.', 'All of them almost empty.', 'This is unacceptable when there are others that simply don’t show or as mentioned, are often half an hour late.', 'We have the worst public transport for a major city in Europe, and it’s not cheap, something needs to be fixed.', 'I had gone mad all night looking for my wallet, lost all hope and decided to go home.', 'When I got on the 42n Wayne, the bus driver, recognised me as I got on.', 'He asked me if I had lost my wallet, called the inspector after he got a better look to confirm it was me.', 'All in the span of 5-10 minutes the inspector came with my wallet, thank you Wayne and the inspector absolutely saved me an absolutely massive headache.', 'Good people in Dublin bus.', '0/5 or if possible I ll rate in minus.', "It's hell, unpredictable, uncomfortable and cost a lot of nerves.", 'For common people with work schedule or study or other important business every minute can count but the buses are so unpredictable - sometimes they delayed, sometimes they even dont come, the system is terrible.', 'Especially during cold the waiting turns to torture']

# %%
from nltk.tokenize import word_tokenize

# Convert 'text' into tokenized form
tokenized_word = word_tokenize(text)
tokenized_sent = tokenized_word

# Display the tokenize text
print(tokenized_word)
# Out:
# ['I', 'was', 'trying', 'to', 'go', 'to', 'the', 'square', 'from', 'kimmage', '.', 'I', 'was', 'waiting', 'for', 'the', 'bus', 'in', 'the', 'freezing', 'cold', 'and', 'kept', 'waiting', 'and', 'waiting', 'and', 'then', 'it', 'got', 'cancelled', ',', 'I', 'had', 'to', 'wait', 'for', 'the', 'next', 'bus', 'that', 'was', 'in', 'an', 'hour', '.', 'Again', 'I', 'waited', 'but', 'it', 'kept', 'getting', 'delayed', 'at', 'the', 'end', 'it', 'got', 'delayed', '30', 'minutes', 'and', 'then', 'it', 'got', 'cancelled', 'again', '!', 'And', 'so', 'I', 'wasted', '1', 'hour', 'and', '30', 'minutes', 'for', 'the', 'bus', 'that', 'didn', '’', 't', 'even', 'come', '?', 'I', '’', 'm', 'disappointed', '.', 'I', '’', 've', 'been', 'getting', 'the', 'bus', 'to', 'work', 'for', 'almost', '20', 'years', ',', 'and', 'it', 'was', 'never', 'great', ',', 'but', 'it', 'has', 'gotten', 'steadily', 'worse', 'over', 'the', 'past', 'few', 'years', 'but', 'especially', 'the', 'last', 'year', '.', 'Buses', 'constantly', 'disappear', ',', 'or', 'come', 'extremely', 'late', '-', 'I', 'have', 'waited', 'an', 'extra', '20–30mins', 'for', 'buses', '4/5', 'evenings', 'after', 'work', 'consistently', 'since', 'September', '.', 'The', 'buses', 'in', 'the', 'morning', 'come', 'relatively', 'on', 'time', ',', 'but', 'then', 'sometimes', 'stop', 'for', 'up', 'to', '10', 'mins', '“', 'to', 'get', 'back', 'on', 'schedule', '”', 'when', 'they', 'certainly', 'weren', '’', 't', '10', 'minutes', 'early', '.', 'Was', 'passed', 'by', 'a', 'bus', 'due', '5', 'minutes', 'after', 'mine', 'while', 'we', 'sat', 'waiting', ',', 'which', 'makes', 'no', 'sense', '.', 'There', 'also', 'seems', 'to', 'be', 'endless', 'buses', 'for', 'certain', 'areas', ',', 'Adamstown', 'for', 'example', 'has', 'such', 'an', 'abundance', 'of', 'buses', ',', 'on', 'December', '13th', 'seven', 'C1', '’', 's', ',', 'and', 'one', 'C2', 'passed', 'by', 'my', 'stop', 'within', '10', 'minutes', '.', 'All', 'of', 'them', 'almost', 'empty', '.', 'This', 'is', 'unacceptable', 'when', 'there', 'are', 'others', 'that', 'simply', 'don', '’', 't', 'show', 'or', 'as', 'mentioned', ',', 'are', 'often', 'half', 'an', 'hour', 'late', '.', 'We', 'have', 'the', 'worst', 'public', 'transport', 'for', 'a', 'major', 'city', 'in', 'Europe', ',', 'and', 'it', '’', 's', 'not', 'cheap', ',', 'something', 'needs', 'to', 'be', 'fixed', '.', 'I', 'had', 'gone', 'mad', 'all', 'night', 'looking', 'for', 'my', 'wallet', ',', 'lost', 'all', 'hope', 'and', 'decided', 'to', 'go', 'home', '.', 'When', 'I', 'got', 'on', 'the', '42n', 'Wayne', ',', 'the', 'bus', 'driver', ',', 'recognised', 'me', 'as', 'I', 'got', 'on', '.', 'He', 'asked', 'me', 'if', 'I', 'had', 'lost', 'my', 'wallet', ',', 'called', 'the', 'inspector', 'after', 'he', 'got', 'a', 'better', 'look', 'to', 'confirm', 'it', 'was', 'me', '.', 'All', 'in', 'the', 'span', 'of', '5-10', 'minutes', 'the', 'inspector', 'came', 'with', 'my', 'wallet', ',', 'thank', 'you', 'Wayne', 'and', 'the', 'inspector', 'absolutely', 'saved', 'me', 'an', 'absolutely', 'massive', 'headache', '.', 'Good', 'people', 'in', 'Dublin', 'bus', '.', '0/5', 'or', 'if', 'possible', 'I', 'll', 'rate', 'in', 'minus', '.', 'It', "'s", 'hell', ',', 'unpredictable', ',', 'uncomfortable', 'and', 'cost', 'a', 'lot', 'of', 'nerves', '.', 'For', 'common', 'people', 'with', 'work', 'schedule', 'or', 'study', 'or', 'other', 'important', 'business', 'every', 'minute', 'can', 'count', 'but', 'the', 'buses', 'are', 'so', 'unpredictable', '-', 'sometimes', 'they', 'delayed', ',', 'sometimes', 'they', 'even', 'dont', 'come', ',', 'the', 'system', 'is', 'terrible', '.', 'Especially', 'during', 'cold', 'the', 'waiting', 'turns', 'to', 'torture']

# %%
from nltk.probability import FreqDist

# Calculate the frequency distribution
fdist = FreqDist(tokenized_word)

# Display the frequency distribution
print(fdist)
# Out:
# <FreqDist with 238 samples and 475 outcomes>

# %%
# Display the most common words
fdist.most_common(5)
# Out:
# [(',', 21), ('the', 20), ('.', 19), ('I', 13), ('to', 11)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt

fdist.plot(30, cumulative = False)
plt.show()

# %%
from nltk.corpus import stopwords

# Load the stop words
stop_words = set(stopwords.words("english"))

# Display the stop words
print(stop_words)
# Out:
# {'re', 'what', "wouldn't", "shouldn't", 'after', 'll', 'my', 'his', "won't", "that'll", 'shan', 'just', 'me', 'out', 'again', 'against', 'being', "doesn't", 'theirs', 'she', 'whom', 'you', 'who', 'such', 'over', 'for', 'until', 'more', 'very', "hadn't", 'or', "aren't", 'nor', 'now', 'where', "you'd", 'wouldn', "you've", 'own', 'above', 'having', 'between', 'into', 'to', 'down', 'ours', 'other', 'can', 'mustn', 'aren', "wasn't", 'have', 'how', 'so', "you're", "hasn't", 'a', "isn't", 'ma', 'before', 'i', 'myself', 'about', "don't", 'are', 'the', 'which', 'shouldn', 'our', "haven't", 'is', 'himself', 'too', 'its', 'of', 'was', 'because', 'they', 'all', 'themselves', 'same', 'yourselves', 'her', 'had', 'o', 'each', 'and', 'wasn', 'then', 'been', 'weren', 'with', 'on', 'that', 'by', 'has', "didn't", 'will', 'm', 'doesn', "it's", 'during', 'hers', 'in', 'y', 'your', 'hadn', 'haven', "weren't", 'further', 'isn', 'these', 'at', 'him', 'from', 'if', 'few', 'there', "she's", 'under', 't', 'most', 'it', 'but', 'am', 'did', 'once', 'some', 's', 'don', 'do', 'needn', "couldn't", 'be', 've', 'herself', 'were', 'off', 'doing', "you'll", 'no', 'he', 'when', 'those', 'any', 'up', 'both', 'only', 'didn', 'hasn', 'than', 'yourself', "shan't", 'not', 'through', "should've", 'them', 'should', "mightn't", 'we', 'does', 'as', 'their', 'below', 'why', 'won', 'yours', 'mightn', 'an', "mustn't", 'here', 'ourselves', 'this', 'd', "needn't", 'couldn', 'itself', 'while', 'ain'}

# %%
# Initialise an array
filtered_sent = []

# for loop for the tokenize sentences
for w in tokenized_sent:
    if w not in stop_words:
        filtered_sent.append(w)

# Display the tokenize and filtered sentences
print("Tokenized Sentence:", tokenized_sent)
print("Filterd Sentence:", filtered_sent)
# Out:
# Tokenized Sentence: ['I', 'was', 'trying', 'to', 'go', 'to', 'the', 'square', 'from', 'kimmage', '.', 'I', 'was', 'waiting', 'for', 'the', 'bus', 'in', 'the', 'freezing', 'cold', 'and', 'kept', 'waiting', 'and', 'waiting', 'and', 'then', 'it', 'got', 'cancelled', ',', 'I', 'had', 'to', 'wait', 'for', 'the', 'next', 'bus', 'that', 'was', 'in', 'an', 'hour', '.', 'Again', 'I', 'waited', 'but', 'it', 'kept', 'getting', 'delayed', 'at', 'the', 'end', 'it', 'got', 'delayed', '30', 'minutes', 'and', 'then', 'it', 'got', 'cancelled', 'again', '!', 'And', 'so', 'I', 'wasted', '1', 'hour', 'and', '30', 'minutes', 'for', 'the', 'bus', 'that', 'didn', '’', 't', 'even', 'come', '?', 'I', '’', 'm', 'disappointed', '.', 'I', '’', 've', 'been', 'getting', 'the', 'bus', 'to', 'work', 'for', 'almost', '20', 'years', ',', 'and', 'it', 'was', 'never', 'great', ',', 'but', 'it', 'has', 'gotten', 'steadily', 'worse', 'over', 'the', 'past', 'few', 'years', 'but', 'especially', 'the', 'last', 'year', '.', 'Buses', 'constantly', 'disappear', ',', 'or', 'come', 'extremely', 'late', '-', 'I', 'have', 'waited', 'an', 'extra', '20–30mins', 'for', 'buses', '4/5', 'evenings', 'after', 'work', 'consistently', 'since', 'September', '.', 'The', 'buses', 'in', 'the', 'morning', 'come', 'relatively', 'on', 'time', ',', 'but', 'then', 'sometimes', 'stop', 'for', 'up', 'to', '10', 'mins', '“', 'to', 'get', 'back', 'on', 'schedule', '”', 'when', 'they', 'certainly', 'weren', '’', 't', '10', 'minutes', 'early', '.', 'Was', 'passed', 'by', 'a', 'bus', 'due', '5', 'minutes', 'after', 'mine', 'while', 'we', 'sat', 'waiting', ',', 'which', 'makes', 'no', 'sense', '.', 'There', 'also', 'seems', 'to', 'be', 'endless', 'buses', 'for', 'certain', 'areas', ',', 'Adamstown', 'for', 'example', 'has', 'such', 'an', 'abundance', 'of', 'buses', ',', 'on', 'December', '13th', 'seven', 'C1', '’', 's', ',', 'and', 'one', 'C2', 'passed', 'by', 'my', 'stop', 'within', '10', 'minutes', '.', 'All', 'of', 'them', 'almost', 'empty', '.', 'This', 'is', 'unacceptable', 'when', 'there', 'are', 'others', 'that', 'simply', 'don', '’', 't', 'show', 'or', 'as', 'mentioned', ',', 'are', 'often', 'half', 'an', 'hour', 'late', '.', 'We', 'have', 'the', 'worst', 'public', 'transport', 'for', 'a', 'major', 'city', 'in', 'Europe', ',', 'and', 'it', '’', 's', 'not', 'cheap', ',', 'something', 'needs', 'to', 'be', 'fixed', '.', 'I', 'had', 'gone', 'mad', 'all', 'night', 'looking', 'for', 'my', 'wallet', ',', 'lost', 'all', 'hope', 'and', 'decided', 'to', 'go', 'home', '.', 'When', 'I', 'got', 'on', 'the', '42n', 'Wayne', ',', 'the', 'bus', 'driver', ',', 'recognised', 'me', 'as', 'I', 'got', 'on', '.', 'He', 'asked', 'me', 'if', 'I', 'had', 'lost', 'my', 'wallet', ',', 'called', 'the', 'inspector', 'after', 'he', 'got', 'a', 'better', 'look', 'to', 'confirm', 'it', 'was', 'me', '.', 'All', 'in', 'the', 'span', 'of', '5-10', 'minutes', 'the', 'inspector', 'came', 'with', 'my', 'wallet', ',', 'thank', 'you', 'Wayne', 'and', 'the', 'inspector', 'absolutely', 'saved', 'me', 'an', 'absolutely', 'massive', 'headache', '.', 'Good', 'people', 'in', 'Dublin', 'bus', '.', '0/5', 'or', 'if', 'possible', 'I', 'll', 'rate', 'in', 'minus', '.', 'It', "'s", 'hell', ',', 'unpredictable', ',', 'uncomfortable', 'and', 'cost', 'a', 'lot', 'of', 'nerves', '.', 'For', 'common', 'people', 'with', 'work', 'schedule', 'or', 'study', 'or', 'other', 'important', 'business', 'every', 'minute', 'can', 'count', 'but', 'the', 'buses', 'are', 'so', 'unpredictable', '-', 'sometimes', 'they', 'delayed', ',', 'sometimes', 'they', 'even', 'dont', 'come', ',', 'the', 'system', 'is', 'terrible', '.', 'Especially', 'during', 'cold', 'the', 'waiting', 'turns', 'to', 'torture']
# Filterd Sentence: ['I', 'trying', 'go', 'square', 'kimmage', '.', 'I', 'waiting', 'bus', 'freezing', 'cold', 'kept', 'waiting', 'waiting', 'got', 'cancelled', ',', 'I', 'wait', 'next', 'bus', 'hour', '.', 'Again', 'I', 'waited', 'kept', 'getting', 'delayed', 'end', 'got', 'delayed', '30', 'minutes', 'got', 'cancelled', '!', 'And', 'I', 'wasted', '1', 'hour', '30', 'minutes', 'bus', '’', 'even', 'come', '?', 'I', '’', 'disappointed', '.', 'I', '’', 'getting', 'bus', 'work', 'almost', '20', 'years', ',', 'never', 'great', ',', 'gotten', 'steadily', 'worse', 'past', 'years', 'especially', 'last', 'year', '.', 'Buses', 'constantly', 'disappear', ',', 'come', 'extremely', 'late', '-', 'I', 'waited', 'extra', '20–30mins', 'buses', '4/5', 'evenings', 'work', 'consistently', 'since', 'September', '.', 'The', 'buses', 'morning', 'come', 'relatively', 'time', ',', 'sometimes', 'stop', '10', 'mins', '“', 'get', 'back', 'schedule', '”', 'certainly', '’', '10', 'minutes', 'early', '.', 'Was', 'passed', 'bus', 'due', '5', 'minutes', 'mine', 'sat', 'waiting', ',', 'makes', 'sense', '.', 'There', 'also', 'seems', 'endless', 'buses', 'certain', 'areas', ',', 'Adamstown', 'example', 'abundance', 'buses', ',', 'December', '13th', 'seven', 'C1', '’', ',', 'one', 'C2', 'passed', 'stop', 'within', '10', 'minutes', '.', 'All', 'almost', 'empty', '.', 'This', 'unacceptable', 'others', 'simply', '’', 'show', 'mentioned', ',', 'often', 'half', 'hour', 'late', '.', 'We', 'worst', 'public', 'transport', 'major', 'city', 'Europe', ',', '’', 'cheap', ',', 'something', 'needs', 'fixed', '.', 'I', 'gone', 'mad', 'night', 'looking', 'wallet', ',', 'lost', 'hope', 'decided', 'go', 'home', '.', 'When', 'I', 'got', '42n', 'Wayne', ',', 'bus', 'driver', ',', 'recognised', 'I', 'got', '.', 'He', 'asked', 'I', 'lost', 'wallet', ',', 'called', 'inspector', 'got', 'better', 'look', 'confirm', '.', 'All', 'span', '5-10', 'minutes', 'inspector', 'came', 'wallet', ',', 'thank', 'Wayne', 'inspector', 'absolutely', 'saved', 'absolutely', 'massive', 'headache', '.', 'Good', 'people', 'Dublin', 'bus', '.', '0/5', 'possible', 'I', 'rate', 'minus', '.', 'It', "'s", 'hell', ',', 'unpredictable', ',', 'uncomfortable', 'cost', 'lot', 'nerves', '.', 'For', 'common', 'people', 'work', 'schedule', 'study', 'important', 'business', 'every', 'minute', 'count', 'buses', 'unpredictable', '-', 'sometimes', 'delayed', ',', 'sometimes', 'even', 'dont', 'come', ',', 'system', 'terrible', '.', 'Especially', 'cold', 'waiting', 'turns', 'torture']

# %%
# Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# Create an initialise an object ps by calling a method PorterStemmer()
ps = PorterStemmer()

# Initialise an array 'stemmed_words'
stemmed_words = []

# Store all the words into an array 'stemmed_words'
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

# Display the stemmed_words
print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['I', 'trying', 'go', 'square', 'kimmage', '.', 'I', 'waiting', 'bus', 'freezing', 'cold', 'kept', 'waiting', 'waiting', 'got', 'cancelled', ',', 'I', 'wait', 'next', 'bus', 'hour', '.', 'Again', 'I', 'waited', 'kept', 'getting', 'delayed', 'end', 'got', 'delayed', '30', 'minutes', 'got', 'cancelled', '!', 'And', 'I', 'wasted', '1', 'hour', '30', 'minutes', 'bus', '’', 'even', 'come', '?', 'I', '’', 'disappointed', '.', 'I', '’', 'getting', 'bus', 'work', 'almost', '20', 'years', ',', 'never', 'great', ',', 'gotten', 'steadily', 'worse', 'past', 'years', 'especially', 'last', 'year', '.', 'Buses', 'constantly', 'disappear', ',', 'come', 'extremely', 'late', '-', 'I', 'waited', 'extra', '20–30mins', 'buses', '4/5', 'evenings', 'work', 'consistently', 'since', 'September', '.', 'The', 'buses', 'morning', 'come', 'relatively', 'time', ',', 'sometimes', 'stop', '10', 'mins', '“', 'get', 'back', 'schedule', '”', 'certainly', '’', '10', 'minutes', 'early', '.', 'Was', 'passed', 'bus', 'due', '5', 'minutes', 'mine', 'sat', 'waiting', ',', 'makes', 'sense', '.', 'There', 'also', 'seems', 'endless', 'buses', 'certain', 'areas', ',', 'Adamstown', 'example', 'abundance', 'buses', ',', 'December', '13th', 'seven', 'C1', '’', ',', 'one', 'C2', 'passed', 'stop', 'within', '10', 'minutes', '.', 'All', 'almost', 'empty', '.', 'This', 'unacceptable', 'others', 'simply', '’', 'show', 'mentioned', ',', 'often', 'half', 'hour', 'late', '.', 'We', 'worst', 'public', 'transport', 'major', 'city', 'Europe', ',', '’', 'cheap', ',', 'something', 'needs', 'fixed', '.', 'I', 'gone', 'mad', 'night', 'looking', 'wallet', ',', 'lost', 'hope', 'decided', 'go', 'home', '.', 'When', 'I', 'got', '42n', 'Wayne', ',', 'bus', 'driver', ',', 'recognised', 'I', 'got', '.', 'He', 'asked', 'I', 'lost', 'wallet', ',', 'called', 'inspector', 'got', 'better', 'look', 'confirm', '.', 'All', 'span', '5-10', 'minutes', 'inspector', 'came', 'wallet', ',', 'thank', 'Wayne', 'inspector', 'absolutely', 'saved', 'absolutely', 'massive', 'headache', '.', 'Good', 'people', 'Dublin', 'bus', '.', '0/5', 'possible', 'I', 'rate', 'minus', '.', 'It', "'s", 'hell', ',', 'unpredictable', ',', 'uncomfortable', 'cost', 'lot', 'nerves', '.', 'For', 'common', 'people', 'work', 'schedule', 'study', 'important', 'business', 'every', 'minute', 'count', 'buses', 'unpredictable', '-', 'sometimes', 'delayed', ',', 'sometimes', 'even', 'dont', 'come', ',', 'system', 'terrible', '.', 'Especially', 'cold', 'waiting', 'turns', 'torture']
# Stemmed Sentence: ['i', 'tri', 'go', 'squar', 'kimmag', '.', 'i', 'wait', 'bu', 'freez', 'cold', 'kept', 'wait', 'wait', 'got', 'cancel', ',', 'i', 'wait', 'next', 'bu', 'hour', '.', 'again', 'i', 'wait', 'kept', 'get', 'delay', 'end', 'got', 'delay', '30', 'minut', 'got', 'cancel', '!', 'and', 'i', 'wast', '1', 'hour', '30', 'minut', 'bu', '’', 'even', 'come', '?', 'i', '’', 'disappoint', '.', 'i', '’', 'get', 'bu', 'work', 'almost', '20', 'year', ',', 'never', 'great', ',', 'gotten', 'steadili', 'wors', 'past', 'year', 'especi', 'last', 'year', '.', 'buse', 'constantli', 'disappear', ',', 'come', 'extrem', 'late', '-', 'i', 'wait', 'extra', '20–30min', 'buse', '4/5', 'even', 'work', 'consist', 'sinc', 'septemb', '.', 'the', 'buse', 'morn', 'come', 'rel', 'time', ',', 'sometim', 'stop', '10', 'min', '“', 'get', 'back', 'schedul', '”', 'certainli', '’', '10', 'minut', 'earli', '.', 'wa', 'pass', 'bu', 'due', '5', 'minut', 'mine', 'sat', 'wait', ',', 'make', 'sens', '.', 'there', 'also', 'seem', 'endless', 'buse', 'certain', 'area', ',', 'adamstown', 'exampl', 'abund', 'buse', ',', 'decemb', '13th', 'seven', 'c1', '’', ',', 'one', 'c2', 'pass', 'stop', 'within', '10', 'minut', '.', 'all', 'almost', 'empti', '.', 'thi', 'unaccept', 'other', 'simpli', '’', 'show', 'mention', ',', 'often', 'half', 'hour', 'late', '.', 'we', 'worst', 'public', 'transport', 'major', 'citi', 'europ', ',', '’', 'cheap', ',', 'someth', 'need', 'fix', '.', 'i', 'gone', 'mad', 'night', 'look', 'wallet', ',', 'lost', 'hope', 'decid', 'go', 'home', '.', 'when', 'i', 'got', '42n', 'wayn', ',', 'bu', 'driver', ',', 'recognis', 'i', 'got', '.', 'he', 'ask', 'i', 'lost', 'wallet', ',', 'call', 'inspector', 'got', 'better', 'look', 'confirm', '.', 'all', 'span', '5-10', 'minut', 'inspector', 'came', 'wallet', ',', 'thank', 'wayn', 'inspector', 'absolut', 'save', 'absolut', 'massiv', 'headach', '.', 'good', 'peopl', 'dublin', 'bu', '.', '0/5', 'possibl', 'i', 'rate', 'minu', '.', 'it', "'s", 'hell', ',', 'unpredict', ',', 'uncomfort', 'cost', 'lot', 'nerv', '.', 'for', 'common', 'peopl', 'work', 'schedul', 'studi', 'import', 'busi', 'everi', 'minut', 'count', 'buse', 'unpredict', '-', 'sometim', 'delay', ',', 'sometim', 'even', 'dont', 'come', ',', 'system', 'terribl', '.', 'especi', 'cold', 'wait', 'turn', 'tortur']

# %%
# Lexicon Normalization
# Performing stemming and Lemmatization

from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

# Create an initialise an object 'lem' by calling a method WordNetLemmatizer()
lem = WordNetLemmatizer()

# Create an initialise an object 'stem' by calling a method PorterStemmer()
stem = PorterStemmer()

# Store the word 'flying' into string 'word'
word = "Bus"

# Display the Lemmatized and stemmed words
print("Lemmatized Word:", lem.lemmatize(word, "v"))
print("Stemmed Word:", stem.stem(word))
# Out:
# Lemmatized Word: Bus
# Stemmed Word: bu

# %%
# Store a sentence into an array 'sent'
sent = "In the city center, facing Trinity College, it's pouring rain. On a Monday, waiting for bus 13 for thirty minutes. The public transportation provided by Dublin Bus is shameful."

# %%
# Loading NLTK
import nltk
from nltk.tokenize import sent_tokenize

# Store the 'sent' into an array 'tokens'
tokens = nltk.word_tokenize(sent)

# Display tokens
print(tokens)
# Out:
# ['In', 'the', 'city', 'center', ',', 'facing', 'Trinity', 'College', ',', 'it', "'s", 'pouring', 'rain', '.', 'On', 'a', 'Monday', ',', 'waiting', 'for', 'bus', '13', 'for', 'thirty', 'minutes', '.', 'The', 'public', 'transportation', 'provided', 'by', 'Dublin', 'Bus', 'is', 'shameful', '.']

# %%
# Display the parts of speech (pos) for the words in the sentence
# https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
nltk.pos_tag(tokens)
# Out:
# [('In', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('center', 'NN'),
#  (',', ','),
#  ('facing', 'VBG'),
#  ('Trinity', 'NNP'),
#  ('College', 'NNP'),
#  (',', ','),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('pouring', 'VBG'),
#  ('rain', 'NN'),
#  ('.', '.'),
#  ('On', 'IN'),
#  ('a', 'DT'),
#  ('Monday', 'NNP'),
#  (',', ','),
#  ('waiting', 'VBG'),
#  ('for', 'IN'),
#  ('bus', 'NN'),
#  ('13', 'CD'),
#  ('for', 'IN'),
#  ('thirty', 'NN'),
#  ('minutes', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('public', 'JJ'),
#  ('transportation', 'NN'),
#  ('provided', 'VBN'),
#  ('by', 'IN'),
#  ('Dublin', 'NNP'),
#  ('Bus', 'NNP'),
#  ('is', 'VBZ'),
#  ('shameful', 'JJ'),
#  ('.', '.')]

# %%
#Load and prepare data - sentiment analysis

df = pd.read_csv('Reviews2.csv.csv', encoding='ISO-8859-1')
df.head()
# Out:
#                                                 Text  Sentiment
# 0  I was trying to go to the square from kimmage....          0
# 1  Iâve been getting the bus to work for almost...          0
# 2  Constant delays, horrific scheduling, buses di...          0
# 3  I had gone mad all night looking for my wallet...          0
# 4  I am not to write this. But I am writing it an...          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       122 non-null    object
#  1   Sentiment  122 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.0+ KB

# %%
df.groupby('Sentiment').describe()
# Out:
#            Text
#           count unique                                                top freq
# Sentiment
# 0            60     60  I was trying to go to the square from kimmage....    1
# 1            62     62  An awful work culture at this company. It's ro...    1

# %%
#No duplicates no need to drop

# %% [markdown]
# Use CountVectorizer to vectorize the text in the DataFrame's "Text" column using a built-in dictionary of stop words. Set min_df to 20 to ignore words that appear less than 3 times in the corpus of training text. This reduces the likelihood of out-of-memory errors and will probably make the model more accurate as well. Also use the ngram_range parameter to allow CountVectorizer to rank word pairs as well as individual words.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(ngram_range = (1, 2), stop_words = 'english', min_df = 3)
x = vectorizer.fit_transform(df['Text'])
y = df['Sentiment']

# %%
text = vectorizer.transform(['The long l3ines   and; pOOr customer# service really turned me off...123.'])
text = vectorizer.inverse_transform(text)
print(text)
# Out:
# [array(['customer', 'long', 'poor', 'really', 'service'], dtype='<U22')]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

#DublinBusReviews
model = LogisticRegression(max_iter = 1000, random_state = 0)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=0)

# %%
# %matplotlib inline
from sklearn.metrics import ConfusionMatrixDisplay as cmd

cmd.from_estimator(model, x_test, y_test,
                   display_labels=['Negative', 'Positive'],
                   cmap='Blues', xticks_rotation='vertical')

# %%
review = 'The bus was awful, I will never take dublin bus again!.'
model.predict_proba(vectorizer.transform([review]))[0][1]
# Out:
# 0.4480619080532185

# %%
review = 'The driver was really friendly and I enjoyed my bus journey!'
model.predict_proba(vectorizer.transform([review]))[0][1]
# Out:
# 0.3385732902862454

# %%
#sentiment analysis for london bus reviews

# %%
df2 = pd.read_csv('reviewsLondon.csv.csv', encoding='ISO-8859-1')
df2.head()
# Out:
#                                                 Text  Sentiment
# 0  In London, the quality of the bus service is v...          0
# 1  We had a poor experience with route 9. The app...          0
# 2  Unbelievable bad service. The bus driver would...          0
# 3  One of those must do items while in London. We...          0
# 4  The service was incredible and reliable. If yo...          0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       71 non-null     object
#  1   Sentiment  71 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.2+ KB

# %%
df2.groupby('Sentiment').describe()
# Out:
#            Text
#           count unique                                                top freq
# Sentiment
# 0            30     30  In London, the quality of the bus service is v...    1
# 1            41     41  Bridgette Florentino was her name, driving the...    1

# %%
vectorizer = CountVectorizer(ngram_range = (1, 2), stop_words = 'english', min_df = 2)
x1 = vectorizer.fit_transform(df2['Text'])
y1 = df2['Sentiment']

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=0.5, random_state=0)

# %%
#LondonBusReviews
model = LogisticRegression(max_iter = 1000, random_state = 0)
model.fit(x_train1, y_train1)
# Out:
# LogisticRegression(max_iter=1000, random_state=0)

# %%
# %matplotlib inline
from sklearn.metrics import ConfusionMatrixDisplay as cmd

cmd.from_estimator(model, x_test1, y_test1,
                   display_labels=['Negative', 'Positive'],
                   cmap='Greens', xticks_rotation='vertical')

# %%
review = 'The bus was awful, I will never take dublin bus again!.'
model.predict_proba(vectorizer.transform([review]))[0][1]
# Out:
# 0.4480619080532185

# %%
review = 'what an amazing journey!'
model.predict_proba(vectorizer.transform([review]))[0][1]
# Out:
# 0.19783399514708297

# %%
# Out:
# Requirement already satisfied: prettytable in c:\users\leega\anaconda3\envs\notebook\lib\site-packages (3.9.0)
# Requirement already satisfied: wcwidth in c:\users\leega\anaconda3\envs\notebook\lib\site-packages (from prettytable) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from prettytable import PrettyTable

sentimentTable = PrettyTable()

sentimentTable.field_names = ["City", "PP", "PN", "NP", "NN", "Positive prediciton", "Negative prediction"]
sentimentTable.add_row(["Dublin", 10,21,17,13, 0.6337,0.3865])
sentimentTable.add_row(["London", 9,16,5,6, 0.3385,0.4480])
print(sentimentTable)
# Out:
# +--------+----+----+----+----+---------------------+---------------------+
# |  City  | PP | PN | NP | NN | Positive prediciton | Negative prediction |
# +--------+----+----+----+----+---------------------+---------------------+
# | Dublin | 10 | 21 | 17 | 13 |        0.6337       |        0.3865       |
# | London | 9  | 16 | 5  | 6  |        0.3385       |        0.448        |
# +--------+----+----+----+----+---------------------+---------------------+

# %%
from IPython.display import HTML

HTML('''<script>

code_show=true; 

function code_toggle() {

 if (code_show){

 $('div.input').hide();

 } else {

 $('div.input').show();

 }

 code_show = !code_show

} 

$( document ).ready(code_toggle);

</script>

<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
#
# code_show=true;
#
# function code_toggle() {
#
#  if (code_show){
#
#  $('div.input').hide();
#
#  } else {
#
#  $('div.input').show();
#
#  }
#
#  code_show = !code_show
#
# }
#
# $( document ).ready(code_toggle);
#
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\leega\anaconda3\envs\notebook\lib\site-packages (10.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tkinter import *
from PIL import ImageTk,Image
root = Tk()
canvas = Canvas(root, width = 600, height = 600)
canvas.pack()
img = ImageTk.PhotoImage(Image.open("Busmean.PNG"))
canvas.create_image(20, 20, anchor=NW, image=img)
root.mainloop()

# %%
from tkinter import *
from PIL import ImageTk, Image

def show_image():
    img = ImageTk.PhotoImage(Image.open("Busmean.PNG"))
    canvas.create_image(20, 20, anchor=NW, image=img)
    canvas.image = img  
    show_button.pack_forget()  
    exit_button.pack()  

def exit_application():
    root.destroy()  


root = Tk()


canvas = Canvas(root, width=600, height=600)
canvas.pack()


show_button = Button(root, text="Show Image", command=show_image,  width=30, height=10)
show_button.pack(pady=50) #centre the button


exit_button = Button(root, text="Exit application", command=exit_application, width=30, height=10)
exit_button.pack_forget()


root.mainloop()

# %%
from tkinter import *
from PIL import ImageTk, Image

def show_first_image():
    img = ImageTk.PhotoImage(Image.open("Busmean.PNG"))
    canvas.create_image(20, 20, anchor=NW, image=img)
    canvas.image = img
    show_first_button.pack_forget()
    show_second_button.pack()

def show_second_image():
    img = ImageTk.PhotoImage(Image.open("DublinPred.PNG"))
    canvas.create_image(20, 20, anchor=NW, image=img)
    canvas.image = img
    show_second_button.pack_forget()
    show_third_button.pack()

def show_third_image():
    img = ImageTk.PhotoImage(Image.open("LondonPred.PNG"))
    canvas.create_image(20, 20, anchor=NW, image=img)
    canvas.image = img
    show_third_button.pack_forget()
    exit_button.pack()

def exit_application():
    root.destroy()

root = Tk()

canvas = Canvas(root, width=600, height=600)
canvas.pack()

show_first_button = Button(root, text="Show countries mean bus usage per month", command=show_first_image, width=200, height=5)
show_first_button.pack(pady=50)

show_second_button = Button(root, text="Show Dublin prediction of positive and negative reviews", command=show_second_image, width=200, height=5)
show_second_button.pack_forget()

show_third_button = Button(root, text="Show London prediction of positive and negative reviews", command=show_third_image, width=200, height=5)
show_third_button.pack_forget()

exit_button = Button(root, text="Exit", command=exit_application, width=20, height=5)
exit_button.pack_forget()

root.mainloop()
